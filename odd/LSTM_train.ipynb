# %% [markdown]
# #Distance Estimator
# To estimate the real distance(unit: meter) of the object
#
# __Input__: Bounding box coordinates(xmin, ymin, xmax, ymax)
# __Output__: 3D location z of carmera coordinates(z_loc)

# %% [markdown]
# ## Load Module

# %%
from tqdm import tqdm
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import torch
import category_encoders as ce
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader 
from sklearn.preprocessing import StandardScaler
from custom_datasets import CustomDataset
from sklearn.metrics import mean_squared_error
import math
from sklearn.preprocessing import MinMaxScaler,StandardScaler, LabelEncoder

# %%
os.makedirs('./weights', exist_ok=True)

# %% [markdown]
# ## Dataset

# %%
df_train = pd.read_csv('../datasets/iou1_train.csv')
df_valid = pd.read_csv('../datasets/iou1_valid.csv')
df_test = pd.read_csv('../datasets/iou1_test.csv')

# %%
df_train['zloc'].sort_values()
# Out:
# 19668    -1.87
# 15486     1.35
# 299       1.38
# 17113     1.41
# 21012     1.45
#          ...
# 6595     85.38
# 4955     85.70
# 7375     86.18
# 16783    86.24
# 18461    94.44
# Name: zloc, Length: 21616, dtype: float64

# %%
#df_train = df_train[df_train['zloc'] > 0]
#df_valid = df_valid[df_valid['zloc'] > 0]
#df_test = df_test[df_test['zloc'] > 0]

# %%
# zloc 조건
#df_train = df_train[df_train['zloc']<90]
#df_valid = df_valid[df_valid['zloc']<90]
#df_test = df_test[df_test['zloc']<90]

# %%
df_train['class'].unique()
# Out:
# array(['car', 'train', 'person', 'Misc', 'truck', 'bicycle'], dtype=object)

# %%
# onehot encoding
class_dummy = pd.get_dummies(df_train['class'])
df_train = pd.concat([df_train, class_dummy], axis=1)

class_dummy = pd.get_dummies(df_valid['class'])
df_valid = pd.concat([df_valid, class_dummy], axis=1)

class_dummy = pd.get_dummies(df_test['class'])
df_test = pd.concat([df_test, class_dummy], axis=1)

# %%
# TrVd
#df_train = pd.concat([df_train, df_valid], axis=0)

# %%
le = LabelEncoder()
train_label = le.fit_transform(df_train['class'])
df_train['class_num'] = train_label

valid_label = le.fit_transform(df_valid['class'])
df_valid['class_num'] = valid_label

test_label = le.fit_transform(df_test['class'])
df_test['class_num'] = test_label

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21616 entries, 0 to 21615
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   filename         21616 non-null  object
#  1   class            21616 non-null  object
#  2   xmin             21616 non-null  float64
#  3   ymin             21616 non-null  float64
#  4   xmax             21616 non-null  float64
#  5   ymax             21616 non-null  float64
#  6   angle            21616 non-null  float64
#  7   zloc             21616 non-null  float64
#  8   weather          21616 non-null  object
#  9   iou              21616 non-null  float64
#  10  depth_y          21616 non-null  int64
#  11  depth_min        21616 non-null  float64
#  12  depth_mean       21616 non-null  float64
#  13  depth_x          21616 non-null  int64
#  14  depth_median     21616 non-null  float64
#  15  depth_max        21616 non-null  float64
#  16  depth_mean_trim  21616 non-null  float64
#  17  width            21616 non-null  float64
#  18  height           21616 non-null  float64
#  19  Misc             21616 non-null  uint8
#  20  bicycle          21616 non-null  uint8
#  21  car              21616 non-null  uint8
#  22  person           21616 non-null  uint8
#  23  train            21616 non-null  uint8
#  24  truck            21616 non-null  uint8
#  25  class_num        21616 non-null  int32
# dtypes: float64(14), int32(1), int64(2), object(3), uint8(6)
# memory usage: 3.3+ MB

# %%
variable = ['xmin','ymin','xmax','ymax','width', 'height', 'depth_mean_trim', 'depth_mean','depth_median','Misc', 'bicycle', 'car', 'person', 'train', 'truck']
val_length = len(variable)
batch_sz = 24
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# train
train_dataset = CustomDataset(df_train, variable, scaler=True, train=True, onehot=False)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_sz, shuffle=True)
# train_sclaer
scaler_train = train_dataset.scaler

# valid
valid_dataset = CustomDataset(df_valid, variable, True, train=scaler_train, onehot=False)
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_sz, shuffle=True)

# test
test_dataset = CustomDataset(df_test, variable, True, train=scaler_train, onehot=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=len(df_test), shuffle=False)

# %%
from pickle import dump

dump(scaler_train, open('../model/lstm_scaler.pkl', 'wb'))

# %%
val_length # 15
# Out:
# 15

# %%
# look dataset
for idx, batch in enumerate(train_dataloader):
    if idx == 1:
        break
    print(batch[0])
    print(batch[0].shape)
    print(batch[0].dtype)
    print(batch[1])
# Out:
# tensor([[ 2.0993e-01,  3.6716e-01, -4.1033e-02, -7.2244e-01, -7.5934e-01,
#          -8.9075e-01,  1.1423e+00,  1.0394e+00,  1.1668e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 8.4557e-01, -1.3437e+00,  8.0642e-01,  1.3446e+00, -1.2736e-01,
#           1.9118e+00, -9.9231e-01, -1.0432e+00, -1.0124e+00, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00,  2.7976e+00, -8.3873e-02, -1.5777e-01],
#         [-4.3424e-01,  2.7883e-01, -6.6881e-01, -7.8676e-01, -7.0286e-01,
#          -9.2353e-01,  1.4390e+00,  1.4501e+00,  1.4261e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.8881e+00,  1.5236e+00, -2.1430e+00, -1.8712e-01, -7.4823e-01,
#          -7.7999e-01,  7.6210e-01,  6.9061e-01,  7.8127e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.3795e+00,  2.4085e+00,  2.4060e+00,  2.3377e+00,  3.0813e+00,
#           1.4994e+00, -1.3425e+00, -1.3866e+00, -1.3536e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 9.7177e-01, -8.1077e-01,  1.1810e+00, -5.9509e-01,  6.2059e-01,
#          -3.0569e-01, -2.4356e-01, -1.6207e-01, -2.4965e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.0530e+00,  2.3355e-01, -1.1238e+00, -5.5622e-01, -2.0196e-01,
#          -6.6692e-01,  4.7281e-01,  3.9959e-01,  4.9239e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-8.6220e-01,  1.4276e+00, -4.7127e-01,  1.5502e+00,  1.1887e+00,
#           1.0595e+00, -1.0364e+00, -1.0036e+00, -1.0379e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.6520e-01, -2.1984e+00, -1.7067e-01, -7.6058e-01, -1.4714e-02,
#           5.6178e-02,  9.8348e-01,  1.0157e+00,  9.2603e-01, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00, -3.5745e-01, -8.3873e-02,  6.3382e+00],
#         [ 3.2496e-01,  2.2352e-01,  2.7294e-01,  8.9971e-02, -1.6049e-01,
#           7.4041e-03, -5.7373e-01, -4.9670e-01, -5.7517e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.6703e+00, -1.3478e+00, -1.8342e+00,  1.1792e+00, -4.7621e-01,
#           1.7417e+00, -1.0360e+00, -9.6008e-01, -1.0409e+00, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00,  2.7976e+00, -8.3873e-02, -1.5777e-01],
#         [ 8.9077e-01,  1.3951e-01,  1.1286e+00,  5.8824e-01,  7.0757e-01,
#           5.5669e-01, -8.9146e-01, -8.9534e-01, -8.8775e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 6.4506e-01,  4.6508e-01,  5.9665e-01, -4.8154e-02, -1.5307e-01,
#          -2.2879e-01, -4.7758e-01, -4.6161e-01, -4.7289e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.1124e+00, -9.1401e-02,  1.1170e+00,  6.4301e-02,  1.6535e-03,
#           1.0186e-01, -7.9080e-01, -5.7345e-01, -7.5375e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.8855e+00,  1.3425e+00, -1.1603e+00,  2.3019e+00,  2.2081e+00,
#           1.8722e+00, -1.1436e+00, -1.2364e+00, -1.1386e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.8883e+00,  1.5628e+00, -1.6104e+00,  1.9089e+00,  8.5919e-01,
#           1.3797e+00, -1.0768e+00, -1.1799e+00, -1.0709e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.9703e-01,  3.8817e-01, -4.3453e-01, -6.7797e-01, -7.1424e-01,
#          -8.5270e-01,  1.0483e+00,  1.0439e+00,  1.0396e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-4.0711e-01, -2.2994e-01, -4.3626e-01, -4.6875e-01, -8.3485e-02,
#          -3.9794e-01, -3.0406e-02,  3.6937e-02,  2.6830e-02, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 1.5232e+00,  7.9709e-01,  2.4071e+00,  2.3391e+00,  2.6494e+00,
#           2.1205e+00, -1.3689e+00, -1.4562e+00, -1.3674e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [-1.3331e+00, -8.4797e-01, -1.3964e+00,  2.3822e+00, -1.7644e-01,
#           2.7977e+00, -1.2441e+00, -1.3443e+00, -1.2454e+00, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00,  2.7976e+00, -8.3873e-02, -1.5777e-01],
#         [-4.3243e-01,  5.2670e-01, -6.5650e-01, -7.8055e-01, -6.7117e-01,
#          -1.0124e+00,  2.2725e+00,  2.1663e+00,  2.2938e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 4.4530e-01, -2.0440e+00,  2.8872e-01, -9.1357e-01, -4.7721e-01,
#          -1.6192e-01,  7.9864e-01,  7.1172e-01,  8.0472e-01, -7.8384e-02,
#          -4.8150e-02, -2.3530e+00, -3.5745e-01, -8.3873e-02,  6.3382e+00],
#         [-9.3727e-01, -4.0083e-01, -5.7958e-01,  9.3897e-01,  1.0892e+00,
#           1.1284e+00, -9.4582e-01, -7.6718e-01, -9.4108e-01, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01],
#         [ 4.9638e-01, -3.3655e-01,  2.8148e-01, -1.0929e+00, -6.5366e-01,
#          -1.0046e+00,  2.3329e+00,  2.2415e+00,  2.3361e+00, -7.8384e-02,
#          -4.8150e-02,  4.2500e-01, -3.5745e-01, -8.3873e-02, -1.5777e-01]])
# torch.Size([24, 15])
# torch.float32
# tensor([[46.7400],
#         [ 7.6600],
#         [53.7200],
#         [40.1200],
#         [ 3.7200],
#         [23.5600],
#         [33.8900],
#         [ 9.6700],
#         [49.5800],
#         [17.3700],
#         [ 8.3800],
#         [12.4400],
#         [19.9800],
#         [16.1600],
#         [ 8.4300],
#         [ 8.9200],
#         [46.0500],
#         [26.7900],
#         [ 3.3300],
#         [ 5.8200],
#         [54.7700],
#         [44.2300],
#         [11.5000],
#         [67.4600]])

# %% [markdown]
# ## Modeling

# %%
class Zloc_Estimaotor(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim=1):
        super().__init__()
        
        self.rnn = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True, bidirectional=False)
        
        #Layer
        layersize=[294, 146, 72]
        layerlist= []
        n_in=hidden_dim
        for i in layersize:
            layerlist.append(nn.Linear(n_in,i))
            layerlist.append(nn.ReLU())
            #layerlist.append(nn.BatchNorm1d(i))
            #layerlist.append(nn.Dropout(0.1))
            n_in=i           
        layerlist.append(nn.Linear(layersize[-1],1))
        #layerlist.append(nn.Sigmoid())
        
        self.fc=nn.Sequential(*layerlist)

        
    def forward(self, x):
        out, hn = self.rnn(x)
        output = self.fc(out[:,-1])
        return output

# %%
class Zloc_Estimaotor_s(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        
        #Layer
        layersize=[32,64,128,256,128,64,32]
        layerlist= []
        n_in=input_dim
        for i in layersize:
            layerlist.append(nn.Linear(n_in,i))
            layerlist.append(nn.ReLU())
            #layerlist.append(nn.BatchNorm1d(i))
            layerlist.append(nn.Dropout(0.1))
            n_in=i           
        layerlist.append(nn.Linear(layersize[-1],1))
        #layerlist.append(nn.Sigmoid())
        
        self.fc=nn.Sequential(*layerlist)

        
    def forward(self, x):
        #out, hn = self.rnn(x)
        output = self.fc(x)
        return output

# %% [markdown]
# ## Make  variable

# %%
import torch.nn.init as init
#def weight_init(m):
#    if isinstance(m, nn.Linear): # nn.Linear에 있는 가중치에만 적용
#        init.kaiming_uniform_(m.weight.data) # He initialization

# variable 
input_dim = val_length
hidden_dim = 612
layer_dim = 3
        
model = Zloc_Estimaotor(input_dim, hidden_dim, layer_dim)
#model = Zloc_Estimaotor_s(input_dim)
#model.apply(weight_init)
#loss_fn = nn.MSELoss()
loss_fn = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=5e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.5,
                                                       patience = 10,
                                                       mode='min', # 우리는 낮아지는 값을 기대
                                                       verbose=True,
                                                       min_lr=1e-6)
from early_stopping import EarlyStopping
early_stopping = EarlyStopping(30, verbose=True)   

model.to(device)
# Out:
# Zloc_Estimaotor(
#   (rnn): LSTM(15, 612, num_layers=3, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=612, out_features=294, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=294, out_features=146, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=146, out_features=72, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=72, out_features=1, bias=True)
#   )
# )

# %%
# train parameters
def count_parameter(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameter(model) # 5686657
# Out:
# 7776237

# %% [markdown]
# ## Make Train, Valid function

# %%
def train(model, train_dataloader, idx_interval):
    model.train()
    
    train_loss = 0
    train_rmse = 0
    
    for idx, batch in enumerate(train_dataloader):
        optimizer.zero_grad()
        
        inp = batch[0].reshape(len(batch[0]),1,-1)
        
        prediction = model(inp.to(device))
        loss = loss_fn(prediction, batch[1].to(device)).cpu()
        
        # Backpropagation
        loss.backward()
        optimizer.step()
    
        train_loss += loss.item()
        if idx % idx_interval == 0:
            print("Train Epoch: {} [{}/{}] \t Train Loss(MAE): {:.4f} \t Train RMAE: {:.4f}".format(epoch, batch_sz*(idx+1), \
                                                                            len(train_dataloader)*batch_sz, \
                                                                            loss.item(), np.sqrt(loss.item())))
    
    train_loss /= len(train_dataloader)
    train_rmse = np.sqrt(train_loss)
        
    return train_loss, train_rmse

# %%
def evaluate(model, valid_dataloader):
    model.eval()
    
    valid_loss = 0
    valid_rmse = 0
    
    with torch.no_grad():
        for idx, batch in enumerate(valid_dataloader):
            inp = batch[0].reshape(len(batch[0]),1,-1)
            predictions = model(inp.to(device))
            loss = loss_fn(predictions, batch[1].to(device)).cpu()
            valid_loss += loss.item()
            
    valid_loss /= len(valid_dataloader)
    valid_rmse = np.sqrt(valid_loss)
    
    return valid_loss,valid_rmse

# %% [markdown]
# ## Train and Validation

# %%
Epoch = 500
best_mae = 99999
best_train_mae = 99999

train_mae_list = []
valid_mae_list = []


for epoch in range(1,(Epoch+1)):
    train_mae, train_rmae = train(model, train_dataloader, 200)
    valid_mae, valid_rmae = evaluate(model, valid_dataloader)

    print("[Epoch: {} \t Valid MAE: {:.4f}".format(epoch, valid_mae))
    print("[Epoch: {} \t Train MAE: {:.4f}".format(epoch, train_mae))
    
    scheduler.step(valid_mae)       
    # Save model
    if valid_mae < best_mae:
        path = "./weights/ODD_LSTM_612_iou4.pth"
        torch.save(model.state_dict(), path) # 모델의 가중치만 저장 구조는 저장 x..?
        best_mae = valid_mae
        best_train_mae = train_mae
        
    train_mae_list.append(train_mae)
    valid_mae_list.append(valid_mae)
    
    early_stopping(valid_mae, model)
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# Train Epoch: 1 [24/21624] 	 Train Loss(MAE): 2.2337 	 Train RMAE: 1.4945
# Train Epoch: 1 [4824/21624] 	 Train Loss(MAE): 1.6948 	 Train RMAE: 1.3018
# Train Epoch: 1 [9624/21624] 	 Train Loss(MAE): 1.8955 	 Train RMAE: 1.3768
# Train Epoch: 1 [14424/21624] 	 Train Loss(MAE): 2.6585 	 Train RMAE: 1.6305
# Train Epoch: 1 [19224/21624] 	 Train Loss(MAE): 2.8199 	 Train RMAE: 1.6792
# [Epoch: 1 	 Valid MAE: 3.8344
# [Epoch: 1 	 Train MAE: 2.6111
# Validation loss decreased (inf --> 3.834409).  Saving model ...
# Train Epoch: 2 [24/21624] 	 Train Loss(MAE): 3.6250 	 Train RMAE: 1.9039
# Train Epoch: 2 [4824/21624] 	 Train Loss(MAE): 2.4255 	 Train RMAE: 1.5574
# Train Epoch: 2 [9624/21624] 	 Train Loss(MAE): 1.7039 	 Train RMAE: 1.3053
# Train Epoch: 2 [14424/21624] 	 Train Loss(MAE): 1.5846 	 Train RMAE: 1.2588
# Train Epoch: 2 [19224/21624] 	 Train Loss(MAE): 2.8736 	 Train RMAE: 1.6952
# [Epoch: 2 	 Valid MAE: 1.7456
# [Epoch: 2 	 Train MAE: 2.2217
# Validation loss decreased (3.834409 --> 1.745559).  Saving model ...
# Train Epoch: 3 [24/21624] 	 Train Loss(MAE): 2.7149 	 Train RMAE: 1.6477
# Train Epoch: 3 [4824/21624] 	 Train Loss(MAE): 5.0638 	 Train RMAE: 2.2503
# Train Epoch: 3 [9624/21624] 	 Train Loss(MAE): 1.3941 	 Train RMAE: 1.1807
# Train Epoch: 3 [14424/21624] 	 Train Loss(MAE): 2.0385 	 Train RMAE: 1.4277
# Train Epoch: 3 [19224/21624] 	 Train Loss(MAE): 2.0875 	 Train RMAE: 1.4448
# [Epoch: 3 	 Valid MAE: 2.0164
# [Epoch: 3 	 Train MAE: 2.0920
# EarlyStopping counter: 1 out of 30
# Train Epoch: 4 [24/21624] 	 Train Loss(MAE): 1.7816 	 Train RMAE: 1.3348
# Train Epoch: 4 [4824/21624] 	 Train Loss(MAE): 2.1889 	 Train RMAE: 1.4795
# Train Epoch: 4 [9624/21624] 	 Train Loss(MAE): 2.7599 	 Train RMAE: 1.6613
# Train Epoch: 4 [14424/21624] 	 Train Loss(MAE): 2.2610 	 Train RMAE: 1.5036
# Train Epoch: 4 [19224/21624] 	 Train Loss(MAE): 2.9403 	 Train RMAE: 1.7147
# [Epoch: 4 	 Valid MAE: 1.9092
# [Epoch: 4 	 Train MAE: 1.9399
# EarlyStopping counter: 2 out of 30
# Train Epoch: 5 [24/21624] 	 Train Loss(MAE): 1.0662 	 Train RMAE: 1.0326
# Train Epoch: 5 [4824/21624] 	 Train Loss(MAE): 1.9471 	 Train RMAE: 1.3954
# Train Epoch: 5 [9624/21624] 	 Train Loss(MAE): 1.7276 	 Train RMAE: 1.3144
# Train Epoch: 5 [14424/21624] 	 Train Loss(MAE): 1.2373 	 Train RMAE: 1.1123
# Train Epoch: 5 [19224/21624] 	 Train Loss(MAE): 1.9083 	 Train RMAE: 1.3814
# [Epoch: 5 	 Valid MAE: 1.7705
# [Epoch: 5 	 Train MAE: 1.9258
# EarlyStopping counter: 3 out of 30
# Train Epoch: 6 [24/21624] 	 Train Loss(MAE): 1.4400 	 Train RMAE: 1.2000
# Train Epoch: 6 [4824/21624] 	 Train Loss(MAE): 1.9918 	 Train RMAE: 1.4113
# Train Epoch: 6 [9624/21624] 	 Train Loss(MAE): 1.7907 	 Train RMAE: 1.3382
# Train Epoch: 6 [14424/21624] 	 Train Loss(MAE): 2.4809 	 Train RMAE: 1.5751
# Train Epoch: 6 [19224/21624] 	 Train Loss(MAE): 1.8716 	 Train RMAE: 1.3681
# [Epoch: 6 	 Valid MAE: 1.7374
# [Epoch: 6 	 Train MAE: 1.8614
# Validation loss decreased (1.745559 --> 1.737354).  Saving model ...
# Train Epoch: 7 [24/21624] 	 Train Loss(MAE): 1.3990 	 Train RMAE: 1.1828
# Train Epoch: 7 [4824/21624] 	 Train Loss(MAE): 1.5380 	 Train RMAE: 1.2402
# Train Epoch: 7 [9624/21624] 	 Train Loss(MAE): 1.5066 	 Train RMAE: 1.2274
# Train Epoch: 7 [14424/21624] 	 Train Loss(MAE): 0.9545 	 Train RMAE: 0.9770
# Train Epoch: 7 [19224/21624] 	 Train Loss(MAE): 1.7727 	 Train RMAE: 1.3314
# [Epoch: 7 	 Valid MAE: 1.6831
# [Epoch: 7 	 Train MAE: 1.7186
# Validation loss decreased (1.737354 --> 1.683141).  Saving model ...
# Train Epoch: 8 [24/21624] 	 Train Loss(MAE): 1.3914 	 Train RMAE: 1.1796
# Train Epoch: 8 [4824/21624] 	 Train Loss(MAE): 1.9988 	 Train RMAE: 1.4138
# Train Epoch: 8 [9624/21624] 	 Train Loss(MAE): 1.4047 	 Train RMAE: 1.1852
# Train Epoch: 8 [14424/21624] 	 Train Loss(MAE): 1.3689 	 Train RMAE: 1.1700
# Train Epoch: 8 [19224/21624] 	 Train Loss(MAE): 2.1814 	 Train RMAE: 1.4770
# [Epoch: 8 	 Valid MAE: 1.6016
# [Epoch: 8 	 Train MAE: 1.7122
# Validation loss decreased (1.683141 --> 1.601616).  Saving model ...
# Train Epoch: 9 [24/21624] 	 Train Loss(MAE): 2.2638 	 Train RMAE: 1.5046
# Train Epoch: 9 [4824/21624] 	 Train Loss(MAE): 2.2141 	 Train RMAE: 1.4880
# Train Epoch: 9 [9624/21624] 	 Train Loss(MAE): 1.5665 	 Train RMAE: 1.2516
# Train Epoch: 9 [14424/21624] 	 Train Loss(MAE): 2.1086 	 Train RMAE: 1.4521
# Train Epoch: 9 [19224/21624] 	 Train Loss(MAE): 1.5708 	 Train RMAE: 1.2533
# [Epoch: 9 	 Valid MAE: 1.6701
# [Epoch: 9 	 Train MAE: 1.6920
# EarlyStopping counter: 1 out of 30
# Train Epoch: 10 [24/21624] 	 Train Loss(MAE): 0.8744 	 Train RMAE: 0.9351
# Train Epoch: 10 [4824/21624] 	 Train Loss(MAE): 1.3733 	 Train RMAE: 1.1719
# Train Epoch: 10 [9624/21624] 	 Train Loss(MAE): 1.9223 	 Train RMAE: 1.3865
# Train Epoch: 10 [14424/21624] 	 Train Loss(MAE): 1.6863 	 Train RMAE: 1.2986
# Train Epoch: 10 [19224/21624] 	 Train Loss(MAE): 1.4604 	 Train RMAE: 1.2085
# [Epoch: 10 	 Valid MAE: 1.6124
# [Epoch: 10 	 Train MAE: 1.7144
# EarlyStopping counter: 2 out of 30
# Train Epoch: 11 [24/21624] 	 Train Loss(MAE): 2.0995 	 Train RMAE: 1.4490
# Train Epoch: 11 [4824/21624] 	 Train Loss(MAE): 2.2352 	 Train RMAE: 1.4951
# Train Epoch: 11 [9624/21624] 	 Train Loss(MAE): 1.4016 	 Train RMAE: 1.1839
# Train Epoch: 11 [14424/21624] 	 Train Loss(MAE): 1.2288 	 Train RMAE: 1.1085
# Train Epoch: 11 [19224/21624] 	 Train Loss(MAE): 1.5685 	 Train RMAE: 1.2524
# [Epoch: 11 	 Valid MAE: 1.5623
# [Epoch: 11 	 Train MAE: 1.6791
# Validation loss decreased (1.601616 --> 1.562323).  Saving model ...
# Train Epoch: 12 [24/21624] 	 Train Loss(MAE): 0.8686 	 Train RMAE: 0.9320
# Train Epoch: 12 [4824/21624] 	 Train Loss(MAE): 1.1465 	 Train RMAE: 1.0707
# Train Epoch: 12 [9624/21624] 	 Train Loss(MAE): 1.8155 	 Train RMAE: 1.3474
# Train Epoch: 12 [14424/21624] 	 Train Loss(MAE): 1.7145 	 Train RMAE: 1.3094
# Train Epoch: 12 [19224/21624] 	 Train Loss(MAE): 1.2321 	 Train RMAE: 1.1100
# [Epoch: 12 	 Valid MAE: 1.4753
# [Epoch: 12 	 Train MAE: 1.6620
# Validation loss decreased (1.562323 --> 1.475273).  Saving model ...
# Train Epoch: 13 [24/21624] 	 Train Loss(MAE): 2.0162 	 Train RMAE: 1.4199
# Train Epoch: 13 [4824/21624] 	 Train Loss(MAE): 1.1136 	 Train RMAE: 1.0553
# Train Epoch: 13 [9624/21624] 	 Train Loss(MAE): 1.0650 	 Train RMAE: 1.0320
# Train Epoch: 13 [14424/21624] 	 Train Loss(MAE): 1.4038 	 Train RMAE: 1.1848
# Train Epoch: 13 [19224/21624] 	 Train Loss(MAE): 1.7930 	 Train RMAE: 1.3390
# [Epoch: 13 	 Valid MAE: 1.9757
# [Epoch: 13 	 Train MAE: 1.6735
# EarlyStopping counter: 1 out of 30
# Train Epoch: 14 [24/21624] 	 Train Loss(MAE): 2.0456 	 Train RMAE: 1.4302
# Train Epoch: 14 [4824/21624] 	 Train Loss(MAE): 2.3456 	 Train RMAE: 1.5315
# Train Epoch: 14 [9624/21624] 	 Train Loss(MAE): 1.1747 	 Train RMAE: 1.0838
# Train Epoch: 14 [14424/21624] 	 Train Loss(MAE): 1.5280 	 Train RMAE: 1.2361
# Train Epoch: 14 [19224/21624] 	 Train Loss(MAE): 3.5624 	 Train RMAE: 1.8874
# [Epoch: 14 	 Valid MAE: 1.4914
# [Epoch: 14 	 Train MAE: 1.6127
# EarlyStopping counter: 2 out of 30
# Train Epoch: 15 [24/21624] 	 Train Loss(MAE): 1.6689 	 Train RMAE: 1.2919
# Train Epoch: 15 [4824/21624] 	 Train Loss(MAE): 1.4160 	 Train RMAE: 1.1900
# Train Epoch: 15 [9624/21624] 	 Train Loss(MAE): 1.3254 	 Train RMAE: 1.1512
# Train Epoch: 15 [14424/21624] 	 Train Loss(MAE): 0.9083 	 Train RMAE: 0.9530
# Train Epoch: 15 [19224/21624] 	 Train Loss(MAE): 1.1544 	 Train RMAE: 1.0744
# [Epoch: 15 	 Valid MAE: 1.5003
# [Epoch: 15 	 Train MAE: 1.5836
# EarlyStopping counter: 3 out of 30
# Train Epoch: 16 [24/21624] 	 Train Loss(MAE): 1.6133 	 Train RMAE: 1.2702
# Train Epoch: 16 [4824/21624] 	 Train Loss(MAE): 1.4334 	 Train RMAE: 1.1972
# Train Epoch: 16 [9624/21624] 	 Train Loss(MAE): 1.9776 	 Train RMAE: 1.4063
# Train Epoch: 16 [14424/21624] 	 Train Loss(MAE): 1.1822 	 Train RMAE: 1.0873
# Train Epoch: 16 [19224/21624] 	 Train Loss(MAE): 1.5547 	 Train RMAE: 1.2469
# [Epoch: 16 	 Valid MAE: 1.5986
# [Epoch: 16 	 Train MAE: 1.5717
# EarlyStopping counter: 4 out of 30
# Train Epoch: 17 [24/21624] 	 Train Loss(MAE): 1.4525 	 Train RMAE: 1.2052
# Train Epoch: 17 [4824/21624] 	 Train Loss(MAE): 1.1998 	 Train RMAE: 1.0953
# Train Epoch: 17 [9624/21624] 	 Train Loss(MAE): 1.2090 	 Train RMAE: 1.0996
# Train Epoch: 17 [14424/21624] 	 Train Loss(MAE): 2.0040 	 Train RMAE: 1.4156
# Train Epoch: 17 [19224/21624] 	 Train Loss(MAE): 1.8557 	 Train RMAE: 1.3622
# [Epoch: 17 	 Valid MAE: 1.5653
# [Epoch: 17 	 Train MAE: 1.5815
# EarlyStopping counter: 5 out of 30
# Train Epoch: 18 [24/21624] 	 Train Loss(MAE): 1.3569 	 Train RMAE: 1.1649
# Train Epoch: 18 [4824/21624] 	 Train Loss(MAE): 1.2736 	 Train RMAE: 1.1285
# Train Epoch: 18 [9624/21624] 	 Train Loss(MAE): 1.7434 	 Train RMAE: 1.3204
# Train Epoch: 18 [14424/21624] 	 Train Loss(MAE): 0.8045 	 Train RMAE: 0.8969
# Train Epoch: 18 [19224/21624] 	 Train Loss(MAE): 1.4184 	 Train RMAE: 1.1910
# [Epoch: 18 	 Valid MAE: 1.4968
# [Epoch: 18 	 Train MAE: 1.5707
# EarlyStopping counter: 6 out of 30
# Train Epoch: 19 [24/21624] 	 Train Loss(MAE): 1.4861 	 Train RMAE: 1.2191
# Train Epoch: 19 [4824/21624] 	 Train Loss(MAE): 1.1838 	 Train RMAE: 1.0880
# Train Epoch: 19 [9624/21624] 	 Train Loss(MAE): 2.2089 	 Train RMAE: 1.4862
# Train Epoch: 19 [14424/21624] 	 Train Loss(MAE): 1.6460 	 Train RMAE: 1.2830
# Train Epoch: 19 [19224/21624] 	 Train Loss(MAE): 1.1878 	 Train RMAE: 1.0899
# [Epoch: 19 	 Valid MAE: 1.4963
# [Epoch: 19 	 Train MAE: 1.5498
# EarlyStopping counter: 7 out of 30
# Train Epoch: 20 [24/21624] 	 Train Loss(MAE): 1.1319 	 Train RMAE: 1.0639
# Train Epoch: 20 [4824/21624] 	 Train Loss(MAE): 2.0210 	 Train RMAE: 1.4216
# Train Epoch: 20 [9624/21624] 	 Train Loss(MAE): 1.7888 	 Train RMAE: 1.3375
# Train Epoch: 20 [14424/21624] 	 Train Loss(MAE): 1.5439 	 Train RMAE: 1.2425
# Train Epoch: 20 [19224/21624] 	 Train Loss(MAE): 1.2109 	 Train RMAE: 1.1004
# [Epoch: 20 	 Valid MAE: 1.6051
# [Epoch: 20 	 Train MAE: 1.5000
# EarlyStopping counter: 8 out of 30
# Train Epoch: 21 [24/21624] 	 Train Loss(MAE): 1.3583 	 Train RMAE: 1.1655
# Train Epoch: 21 [4824/21624] 	 Train Loss(MAE): 0.7793 	 Train RMAE: 0.8828
# Train Epoch: 21 [9624/21624] 	 Train Loss(MAE): 1.9750 	 Train RMAE: 1.4053
# Train Epoch: 21 [14424/21624] 	 Train Loss(MAE): 1.9230 	 Train RMAE: 1.3867
# Train Epoch: 21 [19224/21624] 	 Train Loss(MAE): 0.7875 	 Train RMAE: 0.8874
# [Epoch: 21 	 Valid MAE: 1.5933
# [Epoch: 21 	 Train MAE: 1.5367
# EarlyStopping counter: 9 out of 30
# Train Epoch: 22 [24/21624] 	 Train Loss(MAE): 1.6278 	 Train RMAE: 1.2758
# Train Epoch: 22 [4824/21624] 	 Train Loss(MAE): 1.5197 	 Train RMAE: 1.2328
# Train Epoch: 22 [9624/21624] 	 Train Loss(MAE): 1.2044 	 Train RMAE: 1.0975
# Train Epoch: 22 [14424/21624] 	 Train Loss(MAE): 1.2929 	 Train RMAE: 1.1371
# Train Epoch: 22 [19224/21624] 	 Train Loss(MAE): 1.7923 	 Train RMAE: 1.3388
# [Epoch: 22 	 Valid MAE: 1.5340
# [Epoch: 22 	 Train MAE: 1.4935
# EarlyStopping counter: 10 out of 30
# Train Epoch: 23 [24/21624] 	 Train Loss(MAE): 1.4084 	 Train RMAE: 1.1867
# Train Epoch: 23 [4824/21624] 	 Train Loss(MAE): 1.6563 	 Train RMAE: 1.2870
# Train Epoch: 23 [9624/21624] 	 Train Loss(MAE): 1.8639 	 Train RMAE: 1.3652
# Train Epoch: 23 [14424/21624] 	 Train Loss(MAE): 1.7138 	 Train RMAE: 1.3091
# Train Epoch: 23 [19224/21624] 	 Train Loss(MAE): 1.4826 	 Train RMAE: 1.2176
# [Epoch: 23 	 Valid MAE: 1.4723
# [Epoch: 23 	 Train MAE: 1.4931
# Validation loss decreased (1.475273 --> 1.472256).  Saving model ...
# Train Epoch: 24 [24/21624] 	 Train Loss(MAE): 1.5686 	 Train RMAE: 1.2524
# Train Epoch: 24 [4824/21624] 	 Train Loss(MAE): 0.9850 	 Train RMAE: 0.9924
# Train Epoch: 24 [9624/21624] 	 Train Loss(MAE): 0.8693 	 Train RMAE: 0.9323
# Train Epoch: 24 [14424/21624] 	 Train Loss(MAE): 1.4538 	 Train RMAE: 1.2057
# Train Epoch: 24 [19224/21624] 	 Train Loss(MAE): 2.2030 	 Train RMAE: 1.4843
# [Epoch: 24 	 Valid MAE: 1.5293
# [Epoch: 24 	 Train MAE: 1.4918
# EarlyStopping counter: 1 out of 30
# Train Epoch: 25 [24/21624] 	 Train Loss(MAE): 1.6050 	 Train RMAE: 1.2669
# Train Epoch: 25 [4824/21624] 	 Train Loss(MAE): 2.3020 	 Train RMAE: 1.5172
# Train Epoch: 25 [9624/21624] 	 Train Loss(MAE): 0.7592 	 Train RMAE: 0.8713
# Train Epoch: 25 [14424/21624] 	 Train Loss(MAE): 1.3962 	 Train RMAE: 1.1816
# Train Epoch: 25 [19224/21624] 	 Train Loss(MAE): 1.9179 	 Train RMAE: 1.3849
# [Epoch: 25 	 Valid MAE: 1.3834
# [Epoch: 25 	 Train MAE: 1.4942
# Validation loss decreased (1.472256 --> 1.383438).  Saving model ...
# Train Epoch: 26 [24/21624] 	 Train Loss(MAE): 0.9143 	 Train RMAE: 0.9562
# Train Epoch: 26 [4824/21624] 	 Train Loss(MAE): 1.5747 	 Train RMAE: 1.2549
# Train Epoch: 26 [9624/21624] 	 Train Loss(MAE): 1.9686 	 Train RMAE: 1.4031
# Train Epoch: 26 [14424/21624] 	 Train Loss(MAE): 1.7356 	 Train RMAE: 1.3174
# Train Epoch: 26 [19224/21624] 	 Train Loss(MAE): 1.8929 	 Train RMAE: 1.3758
# [Epoch: 26 	 Valid MAE: 1.4097
# [Epoch: 26 	 Train MAE: 1.4789
# EarlyStopping counter: 1 out of 30
# Train Epoch: 27 [24/21624] 	 Train Loss(MAE): 1.9133 	 Train RMAE: 1.3832
# Train Epoch: 27 [4824/21624] 	 Train Loss(MAE): 0.9339 	 Train RMAE: 0.9664
# Train Epoch: 27 [9624/21624] 	 Train Loss(MAE): 2.3044 	 Train RMAE: 1.5180
# Train Epoch: 27 [14424/21624] 	 Train Loss(MAE): 1.2686 	 Train RMAE: 1.1263
# Train Epoch: 27 [19224/21624] 	 Train Loss(MAE): 1.8755 	 Train RMAE: 1.3695
# [Epoch: 27 	 Valid MAE: 1.5517
# [Epoch: 27 	 Train MAE: 1.4827
# EarlyStopping counter: 2 out of 30
# Train Epoch: 28 [24/21624] 	 Train Loss(MAE): 1.2871 	 Train RMAE: 1.1345
# Train Epoch: 28 [4824/21624] 	 Train Loss(MAE): 1.9381 	 Train RMAE: 1.3922
# Train Epoch: 28 [9624/21624] 	 Train Loss(MAE): 1.2289 	 Train RMAE: 1.1086
# Train Epoch: 28 [14424/21624] 	 Train Loss(MAE): 1.0361 	 Train RMAE: 1.0179
# Train Epoch: 28 [19224/21624] 	 Train Loss(MAE): 1.9338 	 Train RMAE: 1.3906
# [Epoch: 28 	 Valid MAE: 1.3476
# [Epoch: 28 	 Train MAE: 1.4640
# Validation loss decreased (1.383438 --> 1.347611).  Saving model ...
# Train Epoch: 29 [24/21624] 	 Train Loss(MAE): 1.6254 	 Train RMAE: 1.2749
# Train Epoch: 29 [4824/21624] 	 Train Loss(MAE): 1.3113 	 Train RMAE: 1.1451
# Train Epoch: 29 [9624/21624] 	 Train Loss(MAE): 1.7180 	 Train RMAE: 1.3107
# Train Epoch: 29 [14424/21624] 	 Train Loss(MAE): 1.3666 	 Train RMAE: 1.1690
# Train Epoch: 29 [19224/21624] 	 Train Loss(MAE): 1.3766 	 Train RMAE: 1.1733
# [Epoch: 29 	 Valid MAE: 1.3870
# [Epoch: 29 	 Train MAE: 1.4398
# EarlyStopping counter: 1 out of 30
# Train Epoch: 30 [24/21624] 	 Train Loss(MAE): 1.4673 	 Train RMAE: 1.2113
# Train Epoch: 30 [4824/21624] 	 Train Loss(MAE): 1.5832 	 Train RMAE: 1.2583
# Train Epoch: 30 [9624/21624] 	 Train Loss(MAE): 1.4427 	 Train RMAE: 1.2011
# Train Epoch: 30 [14424/21624] 	 Train Loss(MAE): 0.9409 	 Train RMAE: 0.9700
# Train Epoch: 30 [19224/21624] 	 Train Loss(MAE): 1.3118 	 Train RMAE: 1.1453
# [Epoch: 30 	 Valid MAE: 1.4065
# [Epoch: 30 	 Train MAE: 1.4636
# EarlyStopping counter: 2 out of 30
# Train Epoch: 31 [24/21624] 	 Train Loss(MAE): 0.8396 	 Train RMAE: 0.9163
# Train Epoch: 31 [4824/21624] 	 Train Loss(MAE): 1.6375 	 Train RMAE: 1.2796
# Train Epoch: 31 [9624/21624] 	 Train Loss(MAE): 2.4081 	 Train RMAE: 1.5518
# Train Epoch: 31 [14424/21624] 	 Train Loss(MAE): 1.3317 	 Train RMAE: 1.1540
# Train Epoch: 31 [19224/21624] 	 Train Loss(MAE): 2.2072 	 Train RMAE: 1.4857
# [Epoch: 31 	 Valid MAE: 1.5900
# [Epoch: 31 	 Train MAE: 1.4551
# EarlyStopping counter: 3 out of 30
# Train Epoch: 32 [24/21624] 	 Train Loss(MAE): 1.3330 	 Train RMAE: 1.1546
# Train Epoch: 32 [4824/21624] 	 Train Loss(MAE): 1.4251 	 Train RMAE: 1.1938
# Train Epoch: 32 [9624/21624] 	 Train Loss(MAE): 2.1307 	 Train RMAE: 1.4597
# Train Epoch: 32 [14424/21624] 	 Train Loss(MAE): 1.4300 	 Train RMAE: 1.1958
# Train Epoch: 32 [19224/21624] 	 Train Loss(MAE): 1.8469 	 Train RMAE: 1.3590
# [Epoch: 32 	 Valid MAE: 1.4096
# [Epoch: 32 	 Train MAE: 1.4539
# EarlyStopping counter: 4 out of 30
# Train Epoch: 33 [24/21624] 	 Train Loss(MAE): 1.9263 	 Train RMAE: 1.3879
# Train Epoch: 33 [4824/21624] 	 Train Loss(MAE): 1.2005 	 Train RMAE: 1.0957
# Train Epoch: 33 [9624/21624] 	 Train Loss(MAE): 1.8323 	 Train RMAE: 1.3536
# Train Epoch: 33 [14424/21624] 	 Train Loss(MAE): 1.9591 	 Train RMAE: 1.3997
# Train Epoch: 33 [19224/21624] 	 Train Loss(MAE): 1.0950 	 Train RMAE: 1.0464
# [Epoch: 33 	 Valid MAE: 1.5603
# [Epoch: 33 	 Train MAE: 1.4177
# EarlyStopping counter: 5 out of 30
# Train Epoch: 34 [24/21624] 	 Train Loss(MAE): 1.9607 	 Train RMAE: 1.4002
# Train Epoch: 34 [4824/21624] 	 Train Loss(MAE): 1.4040 	 Train RMAE: 1.1849
# Train Epoch: 34 [9624/21624] 	 Train Loss(MAE): 0.9531 	 Train RMAE: 0.9763
# Train Epoch: 34 [14424/21624] 	 Train Loss(MAE): 1.4710 	 Train RMAE: 1.2129
# Train Epoch: 34 [19224/21624] 	 Train Loss(MAE): 1.1101 	 Train RMAE: 1.0536
# [Epoch: 34 	 Valid MAE: 1.4657
# [Epoch: 34 	 Train MAE: 1.4212
# EarlyStopping counter: 6 out of 30
# Train Epoch: 35 [24/21624] 	 Train Loss(MAE): 2.0159 	 Train RMAE: 1.4198
# Train Epoch: 35 [4824/21624] 	 Train Loss(MAE): 1.8236 	 Train RMAE: 1.3504
# Train Epoch: 35 [9624/21624] 	 Train Loss(MAE): 0.8101 	 Train RMAE: 0.9001
# Train Epoch: 35 [14424/21624] 	 Train Loss(MAE): 1.4256 	 Train RMAE: 1.1940
# Train Epoch: 35 [19224/21624] 	 Train Loss(MAE): 1.3961 	 Train RMAE: 1.1816
# [Epoch: 35 	 Valid MAE: 1.3705
# [Epoch: 35 	 Train MAE: 1.4156
# EarlyStopping counter: 7 out of 30
# Train Epoch: 36 [24/21624] 	 Train Loss(MAE): 1.1879 	 Train RMAE: 1.0899
# Train Epoch: 36 [4824/21624] 	 Train Loss(MAE): 1.2216 	 Train RMAE: 1.1053
# Train Epoch: 36 [9624/21624] 	 Train Loss(MAE): 1.2866 	 Train RMAE: 1.1343
# Train Epoch: 36 [14424/21624] 	 Train Loss(MAE): 2.0439 	 Train RMAE: 1.4296
# Train Epoch: 36 [19224/21624] 	 Train Loss(MAE): 1.0359 	 Train RMAE: 1.0178
# [Epoch: 36 	 Valid MAE: 1.3783
# [Epoch: 36 	 Train MAE: 1.4139
# EarlyStopping counter: 8 out of 30
# Train Epoch: 37 [24/21624] 	 Train Loss(MAE): 1.1616 	 Train RMAE: 1.0778
# Train Epoch: 37 [4824/21624] 	 Train Loss(MAE): 1.0741 	 Train RMAE: 1.0364
# Train Epoch: 37 [9624/21624] 	 Train Loss(MAE): 0.9341 	 Train RMAE: 0.9665
# Train Epoch: 37 [14424/21624] 	 Train Loss(MAE): 1.4464 	 Train RMAE: 1.2027
# Train Epoch: 37 [19224/21624] 	 Train Loss(MAE): 1.9513 	 Train RMAE: 1.3969
# [Epoch: 37 	 Valid MAE: 1.4445
# [Epoch: 37 	 Train MAE: 1.4071
# EarlyStopping counter: 9 out of 30
# Train Epoch: 38 [24/21624] 	 Train Loss(MAE): 1.1414 	 Train RMAE: 1.0684
# Train Epoch: 38 [4824/21624] 	 Train Loss(MAE): 1.5740 	 Train RMAE: 1.2546
# Train Epoch: 38 [9624/21624] 	 Train Loss(MAE): 1.2853 	 Train RMAE: 1.1337
# Train Epoch: 38 [14424/21624] 	 Train Loss(MAE): 1.2282 	 Train RMAE: 1.1082
# Train Epoch: 38 [19224/21624] 	 Train Loss(MAE): 0.9814 	 Train RMAE: 0.9906
# [Epoch: 38 	 Valid MAE: 1.4158
# [Epoch: 38 	 Train MAE: 1.4082
# EarlyStopping counter: 10 out of 30
# Train Epoch: 39 [24/21624] 	 Train Loss(MAE): 1.3004 	 Train RMAE: 1.1403
# Train Epoch: 39 [4824/21624] 	 Train Loss(MAE): 1.2342 	 Train RMAE: 1.1110
# Train Epoch: 39 [9624/21624] 	 Train Loss(MAE): 1.4836 	 Train RMAE: 1.2180
# Train Epoch: 39 [14424/21624] 	 Train Loss(MAE): 0.7963 	 Train RMAE: 0.8924
# Train Epoch: 39 [19224/21624] 	 Train Loss(MAE): 2.5940 	 Train RMAE: 1.6106
# [Epoch: 39 	 Valid MAE: 1.3490
# [Epoch: 39 	 Train MAE: 1.4035
# Epoch    39: reducing learning rate of group 0 to 2.5000e-03.
# EarlyStopping counter: 11 out of 30
# Train Epoch: 40 [24/21624] 	 Train Loss(MAE): 1.2518 	 Train RMAE: 1.1188
# Train Epoch: 40 [4824/21624] 	 Train Loss(MAE): 1.7170 	 Train RMAE: 1.3103
# Train Epoch: 40 [9624/21624] 	 Train Loss(MAE): 0.8077 	 Train RMAE: 0.8987
# Train Epoch: 40 [14424/21624] 	 Train Loss(MAE): 0.7508 	 Train RMAE: 0.8665
# Train Epoch: 40 [19224/21624] 	 Train Loss(MAE): 0.7972 	 Train RMAE: 0.8928
# [Epoch: 40 	 Valid MAE: 1.2950
# [Epoch: 40 	 Train MAE: 1.2985
# Validation loss decreased (1.347611 --> 1.295036).  Saving model ...
# Train Epoch: 41 [24/21624] 	 Train Loss(MAE): 0.9315 	 Train RMAE: 0.9651
# Train Epoch: 41 [4824/21624] 	 Train Loss(MAE): 1.6835 	 Train RMAE: 1.2975
# Train Epoch: 41 [9624/21624] 	 Train Loss(MAE): 1.2444 	 Train RMAE: 1.1155
# Train Epoch: 41 [14424/21624] 	 Train Loss(MAE): 1.1007 	 Train RMAE: 1.0491
# Train Epoch: 41 [19224/21624] 	 Train Loss(MAE): 1.3785 	 Train RMAE: 1.1741
# [Epoch: 41 	 Valid MAE: 1.3105
# [Epoch: 41 	 Train MAE: 1.2974
# EarlyStopping counter: 1 out of 30
# Train Epoch: 42 [24/21624] 	 Train Loss(MAE): 1.6247 	 Train RMAE: 1.2746
# Train Epoch: 42 [4824/21624] 	 Train Loss(MAE): 1.4073 	 Train RMAE: 1.1863
# Train Epoch: 42 [9624/21624] 	 Train Loss(MAE): 1.9868 	 Train RMAE: 1.4095
# Train Epoch: 42 [14424/21624] 	 Train Loss(MAE): 1.3944 	 Train RMAE: 1.1808
# Train Epoch: 42 [19224/21624] 	 Train Loss(MAE): 1.0794 	 Train RMAE: 1.0390
# [Epoch: 42 	 Valid MAE: 1.3247
# [Epoch: 42 	 Train MAE: 1.2876
# EarlyStopping counter: 2 out of 30
# Train Epoch: 43 [24/21624] 	 Train Loss(MAE): 1.1750 	 Train RMAE: 1.0840
# Train Epoch: 43 [4824/21624] 	 Train Loss(MAE): 0.9705 	 Train RMAE: 0.9851
# Train Epoch: 43 [9624/21624] 	 Train Loss(MAE): 0.9287 	 Train RMAE: 0.9637
# Train Epoch: 43 [14424/21624] 	 Train Loss(MAE): 1.5679 	 Train RMAE: 1.2522
# Train Epoch: 43 [19224/21624] 	 Train Loss(MAE): 1.4634 	 Train RMAE: 1.2097
# [Epoch: 43 	 Valid MAE: 1.2902
# [Epoch: 43 	 Train MAE: 1.2972
# Validation loss decreased (1.295036 --> 1.290159).  Saving model ...
# Train Epoch: 44 [24/21624] 	 Train Loss(MAE): 0.9814 	 Train RMAE: 0.9906
# Train Epoch: 44 [4824/21624] 	 Train Loss(MAE): 1.3177 	 Train RMAE: 1.1479
# Train Epoch: 44 [9624/21624] 	 Train Loss(MAE): 1.6933 	 Train RMAE: 1.3013
# Train Epoch: 44 [14424/21624] 	 Train Loss(MAE): 1.0514 	 Train RMAE: 1.0254
# Train Epoch: 44 [19224/21624] 	 Train Loss(MAE): 1.1492 	 Train RMAE: 1.0720
# [Epoch: 44 	 Valid MAE: 1.3273
# [Epoch: 44 	 Train MAE: 1.2898
# EarlyStopping counter: 1 out of 30
# Train Epoch: 45 [24/21624] 	 Train Loss(MAE): 1.6109 	 Train RMAE: 1.2692
# Train Epoch: 45 [4824/21624] 	 Train Loss(MAE): 1.0152 	 Train RMAE: 1.0076
# Train Epoch: 45 [9624/21624] 	 Train Loss(MAE): 1.1690 	 Train RMAE: 1.0812
# Train Epoch: 45 [14424/21624] 	 Train Loss(MAE): 0.9733 	 Train RMAE: 0.9865
# Train Epoch: 45 [19224/21624] 	 Train Loss(MAE): 1.6622 	 Train RMAE: 1.2893
# [Epoch: 45 	 Valid MAE: 1.3607
# [Epoch: 45 	 Train MAE: 1.2791
# EarlyStopping counter: 2 out of 30
# Train Epoch: 46 [24/21624] 	 Train Loss(MAE): 0.9915 	 Train RMAE: 0.9957
# Train Epoch: 46 [4824/21624] 	 Train Loss(MAE): 1.1607 	 Train RMAE: 1.0774
# Train Epoch: 46 [9624/21624] 	 Train Loss(MAE): 0.9940 	 Train RMAE: 0.9970
# Train Epoch: 46 [14424/21624] 	 Train Loss(MAE): 1.0434 	 Train RMAE: 1.0215
# Train Epoch: 46 [19224/21624] 	 Train Loss(MAE): 0.9642 	 Train RMAE: 0.9819
# [Epoch: 46 	 Valid MAE: 1.2950
# [Epoch: 46 	 Train MAE: 1.2729
# EarlyStopping counter: 3 out of 30
# Train Epoch: 47 [24/21624] 	 Train Loss(MAE): 1.7186 	 Train RMAE: 1.3110
# Train Epoch: 47 [4824/21624] 	 Train Loss(MAE): 1.0948 	 Train RMAE: 1.0463
# Train Epoch: 47 [9624/21624] 	 Train Loss(MAE): 1.4297 	 Train RMAE: 1.1957
# Train Epoch: 47 [14424/21624] 	 Train Loss(MAE): 0.8387 	 Train RMAE: 0.9158
# Train Epoch: 47 [19224/21624] 	 Train Loss(MAE): 0.9496 	 Train RMAE: 0.9745
# [Epoch: 47 	 Valid MAE: 1.3711
# [Epoch: 47 	 Train MAE: 1.2742
# EarlyStopping counter: 4 out of 30
# Train Epoch: 48 [24/21624] 	 Train Loss(MAE): 1.1617 	 Train RMAE: 1.0778
# Train Epoch: 48 [4824/21624] 	 Train Loss(MAE): 2.1465 	 Train RMAE: 1.4651
# Train Epoch: 48 [9624/21624] 	 Train Loss(MAE): 0.8713 	 Train RMAE: 0.9334
# Train Epoch: 48 [14424/21624] 	 Train Loss(MAE): 1.1116 	 Train RMAE: 1.0543
# Train Epoch: 48 [19224/21624] 	 Train Loss(MAE): 1.5550 	 Train RMAE: 1.2470
# [Epoch: 48 	 Valid MAE: 1.4935
# [Epoch: 48 	 Train MAE: 1.2783
# EarlyStopping counter: 5 out of 30
# Train Epoch: 49 [24/21624] 	 Train Loss(MAE): 0.8455 	 Train RMAE: 0.9195
# Train Epoch: 49 [4824/21624] 	 Train Loss(MAE): 1.5365 	 Train RMAE: 1.2396
# Train Epoch: 49 [9624/21624] 	 Train Loss(MAE): 0.9300 	 Train RMAE: 0.9643
# Train Epoch: 49 [14424/21624] 	 Train Loss(MAE): 1.6546 	 Train RMAE: 1.2863
# Train Epoch: 49 [19224/21624] 	 Train Loss(MAE): 2.0194 	 Train RMAE: 1.4211
# [Epoch: 49 	 Valid MAE: 1.4820
# [Epoch: 49 	 Train MAE: 1.2658
# EarlyStopping counter: 6 out of 30
# Train Epoch: 50 [24/21624] 	 Train Loss(MAE): 1.4326 	 Train RMAE: 1.1969
# Train Epoch: 50 [4824/21624] 	 Train Loss(MAE): 1.0456 	 Train RMAE: 1.0225
# Train Epoch: 50 [9624/21624] 	 Train Loss(MAE): 1.6305 	 Train RMAE: 1.2769
# Train Epoch: 50 [14424/21624] 	 Train Loss(MAE): 1.7645 	 Train RMAE: 1.3284
# Train Epoch: 50 [19224/21624] 	 Train Loss(MAE): 1.6824 	 Train RMAE: 1.2971
# [Epoch: 50 	 Valid MAE: 1.2839
# [Epoch: 50 	 Train MAE: 1.2527
# Validation loss decreased (1.290159 --> 1.283929).  Saving model ...
# Train Epoch: 51 [24/21624] 	 Train Loss(MAE): 1.6232 	 Train RMAE: 1.2741
# Train Epoch: 51 [4824/21624] 	 Train Loss(MAE): 1.3591 	 Train RMAE: 1.1658
# Train Epoch: 51 [9624/21624] 	 Train Loss(MAE): 1.2477 	 Train RMAE: 1.1170
# Train Epoch: 51 [14424/21624] 	 Train Loss(MAE): 1.2654 	 Train RMAE: 1.1249
# Train Epoch: 51 [19224/21624] 	 Train Loss(MAE): 1.2456 	 Train RMAE: 1.1160
# [Epoch: 51 	 Valid MAE: 1.2700
# [Epoch: 51 	 Train MAE: 1.2530
# Validation loss decreased (1.283929 --> 1.269963).  Saving model ...
# Train Epoch: 52 [24/21624] 	 Train Loss(MAE): 0.6204 	 Train RMAE: 0.7877
# Train Epoch: 52 [4824/21624] 	 Train Loss(MAE): 0.8801 	 Train RMAE: 0.9381
# Train Epoch: 52 [9624/21624] 	 Train Loss(MAE): 1.4930 	 Train RMAE: 1.2219
# Train Epoch: 52 [14424/21624] 	 Train Loss(MAE): 1.0992 	 Train RMAE: 1.0484
# Train Epoch: 52 [19224/21624] 	 Train Loss(MAE): 1.6408 	 Train RMAE: 1.2809
# [Epoch: 52 	 Valid MAE: 1.3117
# [Epoch: 52 	 Train MAE: 1.2518
# EarlyStopping counter: 1 out of 30
# Train Epoch: 53 [24/21624] 	 Train Loss(MAE): 1.4028 	 Train RMAE: 1.1844
# Train Epoch: 53 [4824/21624] 	 Train Loss(MAE): 1.6978 	 Train RMAE: 1.3030
# Train Epoch: 53 [9624/21624] 	 Train Loss(MAE): 1.1240 	 Train RMAE: 1.0602
# Train Epoch: 53 [14424/21624] 	 Train Loss(MAE): 1.9870 	 Train RMAE: 1.4096
# Train Epoch: 53 [19224/21624] 	 Train Loss(MAE): 1.2857 	 Train RMAE: 1.1339
# [Epoch: 53 	 Valid MAE: 1.2960
# [Epoch: 53 	 Train MAE: 1.2500
# EarlyStopping counter: 2 out of 30
# Train Epoch: 54 [24/21624] 	 Train Loss(MAE): 0.8823 	 Train RMAE: 0.9393
# Train Epoch: 54 [4824/21624] 	 Train Loss(MAE): 1.4059 	 Train RMAE: 1.1857
# Train Epoch: 54 [9624/21624] 	 Train Loss(MAE): 1.3673 	 Train RMAE: 1.1693
# Train Epoch: 54 [14424/21624] 	 Train Loss(MAE): 0.9508 	 Train RMAE: 0.9751
# Train Epoch: 54 [19224/21624] 	 Train Loss(MAE): 0.8340 	 Train RMAE: 0.9132
# [Epoch: 54 	 Valid MAE: 1.4110
# [Epoch: 54 	 Train MAE: 1.2534
# EarlyStopping counter: 3 out of 30
# Train Epoch: 55 [24/21624] 	 Train Loss(MAE): 2.2553 	 Train RMAE: 1.5018
# Train Epoch: 55 [4824/21624] 	 Train Loss(MAE): 1.2601 	 Train RMAE: 1.1226
# Train Epoch: 55 [9624/21624] 	 Train Loss(MAE): 1.3112 	 Train RMAE: 1.1451
# Train Epoch: 55 [14424/21624] 	 Train Loss(MAE): 1.3287 	 Train RMAE: 1.1527
# Train Epoch: 55 [19224/21624] 	 Train Loss(MAE): 0.7568 	 Train RMAE: 0.8700
# [Epoch: 55 	 Valid MAE: 1.3300
# [Epoch: 55 	 Train MAE: 1.2376
# EarlyStopping counter: 4 out of 30
# Train Epoch: 56 [24/21624] 	 Train Loss(MAE): 1.1174 	 Train RMAE: 1.0571
# Train Epoch: 56 [4824/21624] 	 Train Loss(MAE): 0.9722 	 Train RMAE: 0.9860
# Train Epoch: 56 [9624/21624] 	 Train Loss(MAE): 1.1986 	 Train RMAE: 1.0948
# Train Epoch: 56 [14424/21624] 	 Train Loss(MAE): 1.3742 	 Train RMAE: 1.1723
# Train Epoch: 56 [19224/21624] 	 Train Loss(MAE): 2.0925 	 Train RMAE: 1.4465
# [Epoch: 56 	 Valid MAE: 1.2731
# [Epoch: 56 	 Train MAE: 1.2401
# EarlyStopping counter: 5 out of 30
# Train Epoch: 57 [24/21624] 	 Train Loss(MAE): 0.7019 	 Train RMAE: 0.8378
# Train Epoch: 57 [4824/21624] 	 Train Loss(MAE): 1.0028 	 Train RMAE: 1.0014
# Train Epoch: 57 [9624/21624] 	 Train Loss(MAE): 0.8760 	 Train RMAE: 0.9359
# Train Epoch: 57 [14424/21624] 	 Train Loss(MAE): 1.0098 	 Train RMAE: 1.0049
# Train Epoch: 57 [19224/21624] 	 Train Loss(MAE): 1.4135 	 Train RMAE: 1.1889
# [Epoch: 57 	 Valid MAE: 1.3849
# [Epoch: 57 	 Train MAE: 1.2421
# EarlyStopping counter: 6 out of 30
# Train Epoch: 58 [24/21624] 	 Train Loss(MAE): 1.9101 	 Train RMAE: 1.3821
# Train Epoch: 58 [4824/21624] 	 Train Loss(MAE): 1.2507 	 Train RMAE: 1.1184
# Train Epoch: 58 [9624/21624] 	 Train Loss(MAE): 1.7365 	 Train RMAE: 1.3177
# Train Epoch: 58 [14424/21624] 	 Train Loss(MAE): 0.6936 	 Train RMAE: 0.8328
# Train Epoch: 58 [19224/21624] 	 Train Loss(MAE): 1.2022 	 Train RMAE: 1.0964
# [Epoch: 58 	 Valid MAE: 1.3324
# [Epoch: 58 	 Train MAE: 1.2360
# EarlyStopping counter: 7 out of 30
# Train Epoch: 59 [24/21624] 	 Train Loss(MAE): 1.3297 	 Train RMAE: 1.1531
# Train Epoch: 59 [4824/21624] 	 Train Loss(MAE): 0.7940 	 Train RMAE: 0.8911
# Train Epoch: 59 [9624/21624] 	 Train Loss(MAE): 1.4356 	 Train RMAE: 1.1981
# Train Epoch: 59 [14424/21624] 	 Train Loss(MAE): 1.2650 	 Train RMAE: 1.1247
# Train Epoch: 59 [19224/21624] 	 Train Loss(MAE): 1.0995 	 Train RMAE: 1.0486
# [Epoch: 59 	 Valid MAE: 1.2636
# [Epoch: 59 	 Train MAE: 1.2355
# Validation loss decreased (1.269963 --> 1.263588).  Saving model ...
# Train Epoch: 60 [24/21624] 	 Train Loss(MAE): 0.8077 	 Train RMAE: 0.8987
# Train Epoch: 60 [4824/21624] 	 Train Loss(MAE): 1.6376 	 Train RMAE: 1.2797
# Train Epoch: 60 [9624/21624] 	 Train Loss(MAE): 1.0553 	 Train RMAE: 1.0273
# Train Epoch: 60 [14424/21624] 	 Train Loss(MAE): 1.3263 	 Train RMAE: 1.1516
# Train Epoch: 60 [19224/21624] 	 Train Loss(MAE): 1.7892 	 Train RMAE: 1.3376
# [Epoch: 60 	 Valid MAE: 1.2585
# [Epoch: 60 	 Train MAE: 1.2290
# Validation loss decreased (1.263588 --> 1.258543).  Saving model ...
# Train Epoch: 61 [24/21624] 	 Train Loss(MAE): 0.7370 	 Train RMAE: 0.8585
# Train Epoch: 61 [4824/21624] 	 Train Loss(MAE): 0.7817 	 Train RMAE: 0.8841
# Train Epoch: 61 [9624/21624] 	 Train Loss(MAE): 1.9395 	 Train RMAE: 1.3927
# Train Epoch: 61 [14424/21624] 	 Train Loss(MAE): 1.3352 	 Train RMAE: 1.1555
# Train Epoch: 61 [19224/21624] 	 Train Loss(MAE): 0.5461 	 Train RMAE: 0.7390
# [Epoch: 61 	 Valid MAE: 1.3180
# [Epoch: 61 	 Train MAE: 1.2303
# EarlyStopping counter: 1 out of 30
# Train Epoch: 62 [24/21624] 	 Train Loss(MAE): 0.8638 	 Train RMAE: 0.9294
# Train Epoch: 62 [4824/21624] 	 Train Loss(MAE): 0.7730 	 Train RMAE: 0.8792
# Train Epoch: 62 [9624/21624] 	 Train Loss(MAE): 1.2250 	 Train RMAE: 1.1068
# Train Epoch: 62 [14424/21624] 	 Train Loss(MAE): 1.5127 	 Train RMAE: 1.2299
# Train Epoch: 62 [19224/21624] 	 Train Loss(MAE): 1.8590 	 Train RMAE: 1.3635
# [Epoch: 62 	 Valid MAE: 1.3160
# [Epoch: 62 	 Train MAE: 1.2172
# EarlyStopping counter: 2 out of 30
# Train Epoch: 63 [24/21624] 	 Train Loss(MAE): 0.5701 	 Train RMAE: 0.7551
# Train Epoch: 63 [4824/21624] 	 Train Loss(MAE): 2.0598 	 Train RMAE: 1.4352
# Train Epoch: 63 [9624/21624] 	 Train Loss(MAE): 1.6067 	 Train RMAE: 1.2676
# Train Epoch: 63 [14424/21624] 	 Train Loss(MAE): 1.5866 	 Train RMAE: 1.2596
# Train Epoch: 63 [19224/21624] 	 Train Loss(MAE): 1.3470 	 Train RMAE: 1.1606
# [Epoch: 63 	 Valid MAE: 1.2541
# [Epoch: 63 	 Train MAE: 1.2158
# Validation loss decreased (1.258543 --> 1.254141).  Saving model ...
# Train Epoch: 64 [24/21624] 	 Train Loss(MAE): 0.9731 	 Train RMAE: 0.9864
# Train Epoch: 64 [4824/21624] 	 Train Loss(MAE): 1.0301 	 Train RMAE: 1.0149
# Train Epoch: 64 [9624/21624] 	 Train Loss(MAE): 1.1388 	 Train RMAE: 1.0671
# Train Epoch: 64 [14424/21624] 	 Train Loss(MAE): 1.0105 	 Train RMAE: 1.0053
# Train Epoch: 64 [19224/21624] 	 Train Loss(MAE): 1.2396 	 Train RMAE: 1.1134
# [Epoch: 64 	 Valid MAE: 1.3063
# [Epoch: 64 	 Train MAE: 1.2141
# EarlyStopping counter: 1 out of 30
# Train Epoch: 65 [24/21624] 	 Train Loss(MAE): 1.9173 	 Train RMAE: 1.3847
# Train Epoch: 65 [4824/21624] 	 Train Loss(MAE): 0.6238 	 Train RMAE: 0.7898
# Train Epoch: 65 [9624/21624] 	 Train Loss(MAE): 1.1763 	 Train RMAE: 1.0846
# Train Epoch: 65 [14424/21624] 	 Train Loss(MAE): 0.8989 	 Train RMAE: 0.9481
# Train Epoch: 65 [19224/21624] 	 Train Loss(MAE): 1.4269 	 Train RMAE: 1.1945
# [Epoch: 65 	 Valid MAE: 1.3110
# [Epoch: 65 	 Train MAE: 1.2198
# EarlyStopping counter: 2 out of 30
# Train Epoch: 66 [24/21624] 	 Train Loss(MAE): 1.2522 	 Train RMAE: 1.1190
# Train Epoch: 66 [4824/21624] 	 Train Loss(MAE): 1.1396 	 Train RMAE: 1.0675
# Train Epoch: 66 [9624/21624] 	 Train Loss(MAE): 1.0078 	 Train RMAE: 1.0039
# Train Epoch: 66 [14424/21624] 	 Train Loss(MAE): 1.1333 	 Train RMAE: 1.0646
# Train Epoch: 66 [19224/21624] 	 Train Loss(MAE): 1.1533 	 Train RMAE: 1.0739
# [Epoch: 66 	 Valid MAE: 1.3155
# [Epoch: 66 	 Train MAE: 1.2083
# EarlyStopping counter: 3 out of 30
# Train Epoch: 67 [24/21624] 	 Train Loss(MAE): 0.9967 	 Train RMAE: 0.9983
# Train Epoch: 67 [4824/21624] 	 Train Loss(MAE): 0.9711 	 Train RMAE: 0.9855
# Train Epoch: 67 [9624/21624] 	 Train Loss(MAE): 0.6660 	 Train RMAE: 0.8161
# Train Epoch: 67 [14424/21624] 	 Train Loss(MAE): 0.9351 	 Train RMAE: 0.9670
# Train Epoch: 67 [19224/21624] 	 Train Loss(MAE): 2.2650 	 Train RMAE: 1.5050
# [Epoch: 67 	 Valid MAE: 1.2860
# [Epoch: 67 	 Train MAE: 1.2161
# EarlyStopping counter: 4 out of 30
# Train Epoch: 68 [24/21624] 	 Train Loss(MAE): 1.3302 	 Train RMAE: 1.1533
# Train Epoch: 68 [4824/21624] 	 Train Loss(MAE): 1.4809 	 Train RMAE: 1.2169
# Train Epoch: 68 [9624/21624] 	 Train Loss(MAE): 0.9645 	 Train RMAE: 0.9821
# Train Epoch: 68 [14424/21624] 	 Train Loss(MAE): 1.0725 	 Train RMAE: 1.0356
# Train Epoch: 68 [19224/21624] 	 Train Loss(MAE): 0.8744 	 Train RMAE: 0.9351
# [Epoch: 68 	 Valid MAE: 1.3630
# [Epoch: 68 	 Train MAE: 1.1995
# EarlyStopping counter: 5 out of 30
# Train Epoch: 69 [24/21624] 	 Train Loss(MAE): 1.0176 	 Train RMAE: 1.0087
# Train Epoch: 69 [4824/21624] 	 Train Loss(MAE): 1.1650 	 Train RMAE: 1.0794
# Train Epoch: 69 [9624/21624] 	 Train Loss(MAE): 1.3631 	 Train RMAE: 1.1675
# Train Epoch: 69 [14424/21624] 	 Train Loss(MAE): 1.6498 	 Train RMAE: 1.2844
# Train Epoch: 69 [19224/21624] 	 Train Loss(MAE): 1.3569 	 Train RMAE: 1.1649
# [Epoch: 69 	 Valid MAE: 1.4124
# [Epoch: 69 	 Train MAE: 1.1994
# EarlyStopping counter: 6 out of 30
# Train Epoch: 70 [24/21624] 	 Train Loss(MAE): 1.1001 	 Train RMAE: 1.0488
# Train Epoch: 70 [4824/21624] 	 Train Loss(MAE): 0.9488 	 Train RMAE: 0.9741
# Train Epoch: 70 [9624/21624] 	 Train Loss(MAE): 1.2233 	 Train RMAE: 1.1060
# Train Epoch: 70 [14424/21624] 	 Train Loss(MAE): 1.4118 	 Train RMAE: 1.1882
# Train Epoch: 70 [19224/21624] 	 Train Loss(MAE): 0.9387 	 Train RMAE: 0.9689
# [Epoch: 70 	 Valid MAE: 1.2707
# [Epoch: 70 	 Train MAE: 1.2020
# EarlyStopping counter: 7 out of 30
# Train Epoch: 71 [24/21624] 	 Train Loss(MAE): 1.0181 	 Train RMAE: 1.0090
# Train Epoch: 71 [4824/21624] 	 Train Loss(MAE): 1.1119 	 Train RMAE: 1.0545
# Train Epoch: 71 [9624/21624] 	 Train Loss(MAE): 1.3698 	 Train RMAE: 1.1704
# Train Epoch: 71 [14424/21624] 	 Train Loss(MAE): 1.0390 	 Train RMAE: 1.0193
# Train Epoch: 71 [19224/21624] 	 Train Loss(MAE): 0.9786 	 Train RMAE: 0.9892
# [Epoch: 71 	 Valid MAE: 1.3512
# [Epoch: 71 	 Train MAE: 1.1927
# EarlyStopping counter: 8 out of 30
# Train Epoch: 72 [24/21624] 	 Train Loss(MAE): 1.4853 	 Train RMAE: 1.2187
# Train Epoch: 72 [4824/21624] 	 Train Loss(MAE): 1.8365 	 Train RMAE: 1.3552
# Train Epoch: 72 [9624/21624] 	 Train Loss(MAE): 0.7927 	 Train RMAE: 0.8904
# Train Epoch: 72 [14424/21624] 	 Train Loss(MAE): 1.0650 	 Train RMAE: 1.0320
# Train Epoch: 72 [19224/21624] 	 Train Loss(MAE): 0.8933 	 Train RMAE: 0.9452
# [Epoch: 72 	 Valid MAE: 1.2508
# [Epoch: 72 	 Train MAE: 1.1977
# Validation loss decreased (1.254141 --> 1.250757).  Saving model ...
# Train Epoch: 73 [24/21624] 	 Train Loss(MAE): 0.7335 	 Train RMAE: 0.8565
# Train Epoch: 73 [4824/21624] 	 Train Loss(MAE): 0.6925 	 Train RMAE: 0.8321
# Train Epoch: 73 [9624/21624] 	 Train Loss(MAE): 1.4107 	 Train RMAE: 1.1877
# Train Epoch: 73 [14424/21624] 	 Train Loss(MAE): 0.6646 	 Train RMAE: 0.8153
# Train Epoch: 73 [19224/21624] 	 Train Loss(MAE): 1.3988 	 Train RMAE: 1.1827
# [Epoch: 73 	 Valid MAE: 1.2751
# [Epoch: 73 	 Train MAE: 1.2028
# EarlyStopping counter: 1 out of 30
# Train Epoch: 74 [24/21624] 	 Train Loss(MAE): 1.9376 	 Train RMAE: 1.3920
# Train Epoch: 74 [4824/21624] 	 Train Loss(MAE): 1.2007 	 Train RMAE: 1.0958
# Train Epoch: 74 [9624/21624] 	 Train Loss(MAE): 1.1723 	 Train RMAE: 1.0827
# Train Epoch: 74 [14424/21624] 	 Train Loss(MAE): 1.3385 	 Train RMAE: 1.1569
# Train Epoch: 74 [19224/21624] 	 Train Loss(MAE): 0.9066 	 Train RMAE: 0.9522
# [Epoch: 74 	 Valid MAE: 1.3207
# [Epoch: 74 	 Train MAE: 1.1982
# EarlyStopping counter: 2 out of 30
# Train Epoch: 75 [24/21624] 	 Train Loss(MAE): 0.9018 	 Train RMAE: 0.9497
# Train Epoch: 75 [4824/21624] 	 Train Loss(MAE): 1.2219 	 Train RMAE: 1.1054
# Train Epoch: 75 [9624/21624] 	 Train Loss(MAE): 0.6077 	 Train RMAE: 0.7795
# Train Epoch: 75 [14424/21624] 	 Train Loss(MAE): 0.6993 	 Train RMAE: 0.8362
# Train Epoch: 75 [19224/21624] 	 Train Loss(MAE): 2.7614 	 Train RMAE: 1.6618
# [Epoch: 75 	 Valid MAE: 1.2472
# [Epoch: 75 	 Train MAE: 1.1934
# Validation loss decreased (1.250757 --> 1.247245).  Saving model ...
# Train Epoch: 76 [24/21624] 	 Train Loss(MAE): 1.3769 	 Train RMAE: 1.1734
# Train Epoch: 76 [4824/21624] 	 Train Loss(MAE): 0.8905 	 Train RMAE: 0.9437
# Train Epoch: 76 [9624/21624] 	 Train Loss(MAE): 1.2017 	 Train RMAE: 1.0962
# Train Epoch: 76 [14424/21624] 	 Train Loss(MAE): 0.9488 	 Train RMAE: 0.9741
# Train Epoch: 76 [19224/21624] 	 Train Loss(MAE): 1.3727 	 Train RMAE: 1.1716
# [Epoch: 76 	 Valid MAE: 1.2543
# [Epoch: 76 	 Train MAE: 1.1864
# EarlyStopping counter: 1 out of 30
# Train Epoch: 77 [24/21624] 	 Train Loss(MAE): 1.4126 	 Train RMAE: 1.1885
# Train Epoch: 77 [4824/21624] 	 Train Loss(MAE): 1.2363 	 Train RMAE: 1.1119
# Train Epoch: 77 [9624/21624] 	 Train Loss(MAE): 1.5816 	 Train RMAE: 1.2576
# Train Epoch: 77 [14424/21624] 	 Train Loss(MAE): 0.5999 	 Train RMAE: 0.7745
# Train Epoch: 77 [19224/21624] 	 Train Loss(MAE): 0.7482 	 Train RMAE: 0.8650
# [Epoch: 77 	 Valid MAE: 1.2555
# [Epoch: 77 	 Train MAE: 1.1819
# EarlyStopping counter: 2 out of 30
# Train Epoch: 78 [24/21624] 	 Train Loss(MAE): 1.1490 	 Train RMAE: 1.0719
# Train Epoch: 78 [4824/21624] 	 Train Loss(MAE): 0.6404 	 Train RMAE: 0.8002
# Train Epoch: 78 [9624/21624] 	 Train Loss(MAE): 1.4171 	 Train RMAE: 1.1904
# Train Epoch: 78 [14424/21624] 	 Train Loss(MAE): 1.0944 	 Train RMAE: 1.0462
# Train Epoch: 78 [19224/21624] 	 Train Loss(MAE): 1.4732 	 Train RMAE: 1.2137
# [Epoch: 78 	 Valid MAE: 1.2856
# [Epoch: 78 	 Train MAE: 1.1770
# EarlyStopping counter: 3 out of 30
# Train Epoch: 79 [24/21624] 	 Train Loss(MAE): 0.9789 	 Train RMAE: 0.9894
# Train Epoch: 79 [4824/21624] 	 Train Loss(MAE): 1.7875 	 Train RMAE: 1.3370
# Train Epoch: 79 [9624/21624] 	 Train Loss(MAE): 1.6650 	 Train RMAE: 1.2904
# Train Epoch: 79 [14424/21624] 	 Train Loss(MAE): 1.5574 	 Train RMAE: 1.2479
# Train Epoch: 79 [19224/21624] 	 Train Loss(MAE): 0.8865 	 Train RMAE: 0.9416
# [Epoch: 79 	 Valid MAE: 1.2666
# [Epoch: 79 	 Train MAE: 1.1841
# EarlyStopping counter: 4 out of 30
# Train Epoch: 80 [24/21624] 	 Train Loss(MAE): 0.7343 	 Train RMAE: 0.8569
# Train Epoch: 80 [4824/21624] 	 Train Loss(MAE): 0.9731 	 Train RMAE: 0.9864
# Train Epoch: 80 [9624/21624] 	 Train Loss(MAE): 1.3642 	 Train RMAE: 1.1680
# Train Epoch: 80 [14424/21624] 	 Train Loss(MAE): 1.0509 	 Train RMAE: 1.0251
# Train Epoch: 80 [19224/21624] 	 Train Loss(MAE): 0.7007 	 Train RMAE: 0.8371
# [Epoch: 80 	 Valid MAE: 1.2341
# [Epoch: 80 	 Train MAE: 1.1695
# Validation loss decreased (1.247245 --> 1.234060).  Saving model ...
# Train Epoch: 81 [24/21624] 	 Train Loss(MAE): 0.8170 	 Train RMAE: 0.9039
# Train Epoch: 81 [4824/21624] 	 Train Loss(MAE): 0.9103 	 Train RMAE: 0.9541
# Train Epoch: 81 [9624/21624] 	 Train Loss(MAE): 1.3977 	 Train RMAE: 1.1823
# Train Epoch: 81 [14424/21624] 	 Train Loss(MAE): 0.9181 	 Train RMAE: 0.9582
# Train Epoch: 81 [19224/21624] 	 Train Loss(MAE): 0.6257 	 Train RMAE: 0.7910
# [Epoch: 81 	 Valid MAE: 1.2882
# [Epoch: 81 	 Train MAE: 1.1722
# EarlyStopping counter: 1 out of 30
# Train Epoch: 82 [24/21624] 	 Train Loss(MAE): 1.5040 	 Train RMAE: 1.2264
# Train Epoch: 82 [4824/21624] 	 Train Loss(MAE): 1.0527 	 Train RMAE: 1.0260
# Train Epoch: 82 [9624/21624] 	 Train Loss(MAE): 1.6263 	 Train RMAE: 1.2753
# Train Epoch: 82 [14424/21624] 	 Train Loss(MAE): 0.7162 	 Train RMAE: 0.8463
# Train Epoch: 82 [19224/21624] 	 Train Loss(MAE): 0.9906 	 Train RMAE: 0.9953
# [Epoch: 82 	 Valid MAE: 1.2592
# [Epoch: 82 	 Train MAE: 1.1761
# EarlyStopping counter: 2 out of 30
# Train Epoch: 83 [24/21624] 	 Train Loss(MAE): 1.8052 	 Train RMAE: 1.3436
# Train Epoch: 83 [4824/21624] 	 Train Loss(MAE): 1.6690 	 Train RMAE: 1.2919
# Train Epoch: 83 [9624/21624] 	 Train Loss(MAE): 2.0858 	 Train RMAE: 1.4442
# Train Epoch: 83 [14424/21624] 	 Train Loss(MAE): 0.8818 	 Train RMAE: 0.9390
# Train Epoch: 83 [19224/21624] 	 Train Loss(MAE): 0.8821 	 Train RMAE: 0.9392
# [Epoch: 83 	 Valid MAE: 1.3628
# [Epoch: 83 	 Train MAE: 1.1697
# EarlyStopping counter: 3 out of 30
# Train Epoch: 84 [24/21624] 	 Train Loss(MAE): 1.3996 	 Train RMAE: 1.1830
# Train Epoch: 84 [4824/21624] 	 Train Loss(MAE): 0.9815 	 Train RMAE: 0.9907
# Train Epoch: 84 [9624/21624] 	 Train Loss(MAE): 0.9129 	 Train RMAE: 0.9554
# Train Epoch: 84 [14424/21624] 	 Train Loss(MAE): 1.0370 	 Train RMAE: 1.0183
# Train Epoch: 84 [19224/21624] 	 Train Loss(MAE): 0.9768 	 Train RMAE: 0.9883
# [Epoch: 84 	 Valid MAE: 1.2793
# [Epoch: 84 	 Train MAE: 1.1648
# EarlyStopping counter: 4 out of 30
# Train Epoch: 85 [24/21624] 	 Train Loss(MAE): 1.0119 	 Train RMAE: 1.0059
# Train Epoch: 85 [4824/21624] 	 Train Loss(MAE): 1.4306 	 Train RMAE: 1.1961
# Train Epoch: 85 [9624/21624] 	 Train Loss(MAE): 1.3974 	 Train RMAE: 1.1821
# Train Epoch: 85 [14424/21624] 	 Train Loss(MAE): 0.9627 	 Train RMAE: 0.9812
# Train Epoch: 85 [19224/21624] 	 Train Loss(MAE): 1.1173 	 Train RMAE: 1.0570
# [Epoch: 85 	 Valid MAE: 1.2891
# [Epoch: 85 	 Train MAE: 1.1558
# EarlyStopping counter: 5 out of 30
# Train Epoch: 86 [24/21624] 	 Train Loss(MAE): 1.3686 	 Train RMAE: 1.1699
# Train Epoch: 86 [4824/21624] 	 Train Loss(MAE): 1.2421 	 Train RMAE: 1.1145
# Train Epoch: 86 [9624/21624] 	 Train Loss(MAE): 0.9754 	 Train RMAE: 0.9876
# Train Epoch: 86 [14424/21624] 	 Train Loss(MAE): 0.7085 	 Train RMAE: 0.8417
# Train Epoch: 86 [19224/21624] 	 Train Loss(MAE): 0.5114 	 Train RMAE: 0.7151
# [Epoch: 86 	 Valid MAE: 1.2569
# [Epoch: 86 	 Train MAE: 1.1622
# EarlyStopping counter: 6 out of 30
# Train Epoch: 87 [24/21624] 	 Train Loss(MAE): 0.9256 	 Train RMAE: 0.9621
# Train Epoch: 87 [4824/21624] 	 Train Loss(MAE): 1.1783 	 Train RMAE: 1.0855
# Train Epoch: 87 [9624/21624] 	 Train Loss(MAE): 1.6603 	 Train RMAE: 1.2885
# Train Epoch: 87 [14424/21624] 	 Train Loss(MAE): 0.7052 	 Train RMAE: 0.8397
# Train Epoch: 87 [19224/21624] 	 Train Loss(MAE): 1.3249 	 Train RMAE: 1.1511
# [Epoch: 87 	 Valid MAE: 1.2801
# [Epoch: 87 	 Train MAE: 1.1761
# EarlyStopping counter: 7 out of 30
# Train Epoch: 88 [24/21624] 	 Train Loss(MAE): 0.9414 	 Train RMAE: 0.9702
# Train Epoch: 88 [4824/21624] 	 Train Loss(MAE): 0.5629 	 Train RMAE: 0.7502
# Train Epoch: 88 [9624/21624] 	 Train Loss(MAE): 1.2641 	 Train RMAE: 1.1243
# Train Epoch: 88 [14424/21624] 	 Train Loss(MAE): 1.2942 	 Train RMAE: 1.1376
# Train Epoch: 88 [19224/21624] 	 Train Loss(MAE): 1.0426 	 Train RMAE: 1.0211
# [Epoch: 88 	 Valid MAE: 1.2551
# [Epoch: 88 	 Train MAE: 1.1635
# EarlyStopping counter: 8 out of 30
# Train Epoch: 89 [24/21624] 	 Train Loss(MAE): 0.8519 	 Train RMAE: 0.9230
# Train Epoch: 89 [4824/21624] 	 Train Loss(MAE): 1.7075 	 Train RMAE: 1.3067
# Train Epoch: 89 [9624/21624] 	 Train Loss(MAE): 1.0882 	 Train RMAE: 1.0432
# Train Epoch: 89 [14424/21624] 	 Train Loss(MAE): 1.8535 	 Train RMAE: 1.3614
# Train Epoch: 89 [19224/21624] 	 Train Loss(MAE): 1.1722 	 Train RMAE: 1.0827
# [Epoch: 89 	 Valid MAE: 1.3097
# [Epoch: 89 	 Train MAE: 1.1478
# EarlyStopping counter: 9 out of 30
# Train Epoch: 90 [24/21624] 	 Train Loss(MAE): 1.2247 	 Train RMAE: 1.1067
# Train Epoch: 90 [4824/21624] 	 Train Loss(MAE): 0.7486 	 Train RMAE: 0.8652
# Train Epoch: 90 [9624/21624] 	 Train Loss(MAE): 1.1563 	 Train RMAE: 1.0753
# Train Epoch: 90 [14424/21624] 	 Train Loss(MAE): 1.4363 	 Train RMAE: 1.1984
# Train Epoch: 90 [19224/21624] 	 Train Loss(MAE): 1.3256 	 Train RMAE: 1.1514
# [Epoch: 90 	 Valid MAE: 1.2849
# [Epoch: 90 	 Train MAE: 1.1544
# EarlyStopping counter: 10 out of 30
# Train Epoch: 91 [24/21624] 	 Train Loss(MAE): 0.6906 	 Train RMAE: 0.8310
# Train Epoch: 91 [4824/21624] 	 Train Loss(MAE): 1.1253 	 Train RMAE: 1.0608
# Train Epoch: 91 [9624/21624] 	 Train Loss(MAE): 1.9368 	 Train RMAE: 1.3917
# Train Epoch: 91 [14424/21624] 	 Train Loss(MAE): 1.1052 	 Train RMAE: 1.0513
# Train Epoch: 91 [19224/21624] 	 Train Loss(MAE): 1.6570 	 Train RMAE: 1.2872
# [Epoch: 91 	 Valid MAE: 1.3567
# [Epoch: 91 	 Train MAE: 1.1641
# Epoch    91: reducing learning rate of group 0 to 1.2500e-03.
# EarlyStopping counter: 11 out of 30
# Train Epoch: 92 [24/21624] 	 Train Loss(MAE): 1.6001 	 Train RMAE: 1.2649
# Train Epoch: 92 [4824/21624] 	 Train Loss(MAE): 0.8891 	 Train RMAE: 0.9429
# Train Epoch: 92 [9624/21624] 	 Train Loss(MAE): 1.7404 	 Train RMAE: 1.3192
# Train Epoch: 92 [14424/21624] 	 Train Loss(MAE): 0.8139 	 Train RMAE: 0.9022
# Train Epoch: 92 [19224/21624] 	 Train Loss(MAE): 0.7285 	 Train RMAE: 0.8535
# [Epoch: 92 	 Valid MAE: 1.2141
# [Epoch: 92 	 Train MAE: 1.1015
# Validation loss decreased (1.234060 --> 1.214105).  Saving model ...
# Train Epoch: 93 [24/21624] 	 Train Loss(MAE): 0.8780 	 Train RMAE: 0.9370
# Train Epoch: 93 [4824/21624] 	 Train Loss(MAE): 1.0963 	 Train RMAE: 1.0470
# Train Epoch: 93 [9624/21624] 	 Train Loss(MAE): 0.7143 	 Train RMAE: 0.8452
# Train Epoch: 93 [14424/21624] 	 Train Loss(MAE): 0.7305 	 Train RMAE: 0.8547
# Train Epoch: 93 [19224/21624] 	 Train Loss(MAE): 1.0554 	 Train RMAE: 1.0273
# [Epoch: 93 	 Valid MAE: 1.2199
# [Epoch: 93 	 Train MAE: 1.0886
# EarlyStopping counter: 1 out of 30
# Train Epoch: 94 [24/21624] 	 Train Loss(MAE): 1.5177 	 Train RMAE: 1.2320
# Train Epoch: 94 [4824/21624] 	 Train Loss(MAE): 0.8578 	 Train RMAE: 0.9262
# Train Epoch: 94 [9624/21624] 	 Train Loss(MAE): 1.0180 	 Train RMAE: 1.0090
# Train Epoch: 94 [14424/21624] 	 Train Loss(MAE): 0.6764 	 Train RMAE: 0.8224
# Train Epoch: 94 [19224/21624] 	 Train Loss(MAE): 0.9515 	 Train RMAE: 0.9755
# [Epoch: 94 	 Valid MAE: 1.2800
# [Epoch: 94 	 Train MAE: 1.0872
# EarlyStopping counter: 2 out of 30
# Train Epoch: 95 [24/21624] 	 Train Loss(MAE): 1.2734 	 Train RMAE: 1.1285
# Train Epoch: 95 [4824/21624] 	 Train Loss(MAE): 0.4921 	 Train RMAE: 0.7015
# Train Epoch: 95 [9624/21624] 	 Train Loss(MAE): 1.0598 	 Train RMAE: 1.0295
# Train Epoch: 95 [14424/21624] 	 Train Loss(MAE): 1.5083 	 Train RMAE: 1.2281
# Train Epoch: 95 [19224/21624] 	 Train Loss(MAE): 0.9699 	 Train RMAE: 0.9849
# [Epoch: 95 	 Valid MAE: 1.2176
# [Epoch: 95 	 Train MAE: 1.0799
# EarlyStopping counter: 3 out of 30
# Train Epoch: 96 [24/21624] 	 Train Loss(MAE): 0.9278 	 Train RMAE: 0.9632
# Train Epoch: 96 [4824/21624] 	 Train Loss(MAE): 0.9650 	 Train RMAE: 0.9824
# Train Epoch: 96 [9624/21624] 	 Train Loss(MAE): 0.6891 	 Train RMAE: 0.8301
# Train Epoch: 96 [14424/21624] 	 Train Loss(MAE): 0.8574 	 Train RMAE: 0.9260
# Train Epoch: 96 [19224/21624] 	 Train Loss(MAE): 0.8281 	 Train RMAE: 0.9100
# [Epoch: 96 	 Valid MAE: 1.2583
# [Epoch: 96 	 Train MAE: 1.0780
# EarlyStopping counter: 4 out of 30
# Train Epoch: 97 [24/21624] 	 Train Loss(MAE): 0.9269 	 Train RMAE: 0.9627
# Train Epoch: 97 [4824/21624] 	 Train Loss(MAE): 0.3506 	 Train RMAE: 0.5921
# Train Epoch: 97 [9624/21624] 	 Train Loss(MAE): 0.7628 	 Train RMAE: 0.8734
# Train Epoch: 97 [14424/21624] 	 Train Loss(MAE): 0.9126 	 Train RMAE: 0.9553
# Train Epoch: 97 [19224/21624] 	 Train Loss(MAE): 1.0739 	 Train RMAE: 1.0363
# [Epoch: 97 	 Valid MAE: 1.3488
# [Epoch: 97 	 Train MAE: 1.0856
# EarlyStopping counter: 5 out of 30
# Train Epoch: 98 [24/21624] 	 Train Loss(MAE): 0.9728 	 Train RMAE: 0.9863
# Train Epoch: 98 [4824/21624] 	 Train Loss(MAE): 1.1782 	 Train RMAE: 1.0854
# Train Epoch: 98 [9624/21624] 	 Train Loss(MAE): 0.5818 	 Train RMAE: 0.7628
# Train Epoch: 98 [14424/21624] 	 Train Loss(MAE): 0.9017 	 Train RMAE: 0.9496
# Train Epoch: 98 [19224/21624] 	 Train Loss(MAE): 0.7895 	 Train RMAE: 0.8885
# [Epoch: 98 	 Valid MAE: 1.3098
# [Epoch: 98 	 Train MAE: 1.0802
# EarlyStopping counter: 6 out of 30
# Train Epoch: 99 [24/21624] 	 Train Loss(MAE): 1.5507 	 Train RMAE: 1.2453
# Train Epoch: 99 [4824/21624] 	 Train Loss(MAE): 1.5143 	 Train RMAE: 1.2306
# Train Epoch: 99 [9624/21624] 	 Train Loss(MAE): 0.9602 	 Train RMAE: 0.9799
# Train Epoch: 99 [14424/21624] 	 Train Loss(MAE): 1.3107 	 Train RMAE: 1.1449
# Train Epoch: 99 [19224/21624] 	 Train Loss(MAE): 1.3445 	 Train RMAE: 1.1595
# [Epoch: 99 	 Valid MAE: 1.2331
# [Epoch: 99 	 Train MAE: 1.0712
# EarlyStopping counter: 7 out of 30
# ...
# Train Epoch: 172 [14424/21624] 	 Train Loss(MAE): 0.7309 	 Train RMAE: 0.8549
# Train Epoch: 172 [19224/21624] 	 Train Loss(MAE): 0.8368 	 Train RMAE: 0.9148
# [Epoch: 172 	 Valid MAE: 1.1865
# [Epoch: 172 	 Train MAE: 0.9129
# EarlyStopping counter: 12 out of 30
# Train Epoch: 173 [24/21624] 	 Train Loss(MAE): 0.8923 	 Train RMAE: 0.9446
# Train Epoch: 173 [4824/21624] 	 Train Loss(MAE): 0.4876 	 Train RMAE: 0.6983
# Train Epoch: 173 [9624/21624] 	 Train Loss(MAE): 0.7626 	 Train RMAE: 0.8732
# Train Epoch: 173 [14424/21624] 	 Train Loss(MAE): 1.3082 	 Train RMAE: 1.1437
# Train Epoch: 173 [19224/21624] 	 Train Loss(MAE): 1.3309 	 Train RMAE: 1.1537
# [Epoch: 173 	 Valid MAE: 1.1897
# [Epoch: 173 	 Train MAE: 0.9106
# EarlyStopping counter: 13 out of 30
# Train Epoch: 174 [24/21624] 	 Train Loss(MAE): 1.0084 	 Train RMAE: 1.0042
# Train Epoch: 174 [4824/21624] 	 Train Loss(MAE): 0.7343 	 Train RMAE: 0.8569
# Train Epoch: 174 [9624/21624] 	 Train Loss(MAE): 0.9557 	 Train RMAE: 0.9776
# Train Epoch: 174 [14424/21624] 	 Train Loss(MAE): 0.8004 	 Train RMAE: 0.8947
# Train Epoch: 174 [19224/21624] 	 Train Loss(MAE): 0.5368 	 Train RMAE: 0.7327
# [Epoch: 174 	 Valid MAE: 1.1814
# [Epoch: 174 	 Train MAE: 0.9091
# Validation loss decreased (1.183101 --> 1.181449).  Saving model ...
# Train Epoch: 175 [24/21624] 	 Train Loss(MAE): 1.0965 	 Train RMAE: 1.0471
# Train Epoch: 175 [4824/21624] 	 Train Loss(MAE): 0.8609 	 Train RMAE: 0.9278
# Train Epoch: 175 [9624/21624] 	 Train Loss(MAE): 0.6140 	 Train RMAE: 0.7836
# Train Epoch: 175 [14424/21624] 	 Train Loss(MAE): 0.9546 	 Train RMAE: 0.9771
# Train Epoch: 175 [19224/21624] 	 Train Loss(MAE): 0.9825 	 Train RMAE: 0.9912
# [Epoch: 175 	 Valid MAE: 1.1886
# [Epoch: 175 	 Train MAE: 0.9092
# EarlyStopping counter: 1 out of 30
# Train Epoch: 176 [24/21624] 	 Train Loss(MAE): 0.6754 	 Train RMAE: 0.8218
# Train Epoch: 176 [4824/21624] 	 Train Loss(MAE): 0.8994 	 Train RMAE: 0.9484
# Train Epoch: 176 [9624/21624] 	 Train Loss(MAE): 0.9393 	 Train RMAE: 0.9692
# Train Epoch: 176 [14424/21624] 	 Train Loss(MAE): 0.8865 	 Train RMAE: 0.9416
# Train Epoch: 176 [19224/21624] 	 Train Loss(MAE): 0.3540 	 Train RMAE: 0.5950
# [Epoch: 176 	 Valid MAE: 1.1964
# [Epoch: 176 	 Train MAE: 0.9087
# EarlyStopping counter: 2 out of 30
# Train Epoch: 177 [24/21624] 	 Train Loss(MAE): 1.0082 	 Train RMAE: 1.0041
# Train Epoch: 177 [4824/21624] 	 Train Loss(MAE): 0.5877 	 Train RMAE: 0.7666
# Train Epoch: 177 [9624/21624] 	 Train Loss(MAE): 1.1166 	 Train RMAE: 1.0567
# Train Epoch: 177 [14424/21624] 	 Train Loss(MAE): 0.6216 	 Train RMAE: 0.7884
# Train Epoch: 177 [19224/21624] 	 Train Loss(MAE): 0.9276 	 Train RMAE: 0.9631
# [Epoch: 177 	 Valid MAE: 1.1940
# [Epoch: 177 	 Train MAE: 0.9088
# EarlyStopping counter: 3 out of 30
# Train Epoch: 178 [24/21624] 	 Train Loss(MAE): 0.4295 	 Train RMAE: 0.6554
# Train Epoch: 178 [4824/21624] 	 Train Loss(MAE): 0.8554 	 Train RMAE: 0.9249
# Train Epoch: 178 [9624/21624] 	 Train Loss(MAE): 0.7924 	 Train RMAE: 0.8902
# Train Epoch: 178 [14424/21624] 	 Train Loss(MAE): 0.8141 	 Train RMAE: 0.9023
# Train Epoch: 178 [19224/21624] 	 Train Loss(MAE): 0.8489 	 Train RMAE: 0.9214
# [Epoch: 178 	 Valid MAE: 1.1893
# [Epoch: 178 	 Train MAE: 0.9090
# EarlyStopping counter: 4 out of 30
# Train Epoch: 179 [24/21624] 	 Train Loss(MAE): 1.1578 	 Train RMAE: 1.0760
# Train Epoch: 179 [4824/21624] 	 Train Loss(MAE): 0.8030 	 Train RMAE: 0.8961
# Train Epoch: 179 [9624/21624] 	 Train Loss(MAE): 0.9232 	 Train RMAE: 0.9608
# Train Epoch: 179 [14424/21624] 	 Train Loss(MAE): 0.8702 	 Train RMAE: 0.9328
# Train Epoch: 179 [19224/21624] 	 Train Loss(MAE): 0.7495 	 Train RMAE: 0.8657
# [Epoch: 179 	 Valid MAE: 1.1836
# [Epoch: 179 	 Train MAE: 0.9069
# EarlyStopping counter: 5 out of 30
# Train Epoch: 180 [24/21624] 	 Train Loss(MAE): 0.6662 	 Train RMAE: 0.8162
# Train Epoch: 180 [4824/21624] 	 Train Loss(MAE): 1.1744 	 Train RMAE: 1.0837
# Train Epoch: 180 [9624/21624] 	 Train Loss(MAE): 0.7770 	 Train RMAE: 0.8815
# Train Epoch: 180 [14424/21624] 	 Train Loss(MAE): 0.7082 	 Train RMAE: 0.8415
# Train Epoch: 180 [19224/21624] 	 Train Loss(MAE): 1.1616 	 Train RMAE: 1.0778
# [Epoch: 180 	 Valid MAE: 1.1873
# [Epoch: 180 	 Train MAE: 0.9061
# EarlyStopping counter: 6 out of 30
# Train Epoch: 181 [24/21624] 	 Train Loss(MAE): 0.7347 	 Train RMAE: 0.8571
# Train Epoch: 181 [4824/21624] 	 Train Loss(MAE): 1.1240 	 Train RMAE: 1.0602
# Train Epoch: 181 [9624/21624] 	 Train Loss(MAE): 1.0340 	 Train RMAE: 1.0169
# Train Epoch: 181 [14424/21624] 	 Train Loss(MAE): 0.9131 	 Train RMAE: 0.9555
# Train Epoch: 181 [19224/21624] 	 Train Loss(MAE): 0.9755 	 Train RMAE: 0.9877
# [Epoch: 181 	 Valid MAE: 1.1862
# [Epoch: 181 	 Train MAE: 0.9070
# EarlyStopping counter: 7 out of 30
# Train Epoch: 182 [24/21624] 	 Train Loss(MAE): 0.7519 	 Train RMAE: 0.8671
# Train Epoch: 182 [4824/21624] 	 Train Loss(MAE): 0.5713 	 Train RMAE: 0.7559
# Train Epoch: 182 [9624/21624] 	 Train Loss(MAE): 0.8333 	 Train RMAE: 0.9129
# Train Epoch: 182 [14424/21624] 	 Train Loss(MAE): 0.7575 	 Train RMAE: 0.8704
# Train Epoch: 182 [19224/21624] 	 Train Loss(MAE): 1.1340 	 Train RMAE: 1.0649
# [Epoch: 182 	 Valid MAE: 1.1865
# [Epoch: 182 	 Train MAE: 0.9064
# EarlyStopping counter: 8 out of 30
# Train Epoch: 183 [24/21624] 	 Train Loss(MAE): 0.8173 	 Train RMAE: 0.9040
# Train Epoch: 183 [4824/21624] 	 Train Loss(MAE): 0.6032 	 Train RMAE: 0.7767
# Train Epoch: 183 [9624/21624] 	 Train Loss(MAE): 0.6311 	 Train RMAE: 0.7944
# Train Epoch: 183 [14424/21624] 	 Train Loss(MAE): 0.7899 	 Train RMAE: 0.8888
# Train Epoch: 183 [19224/21624] 	 Train Loss(MAE): 0.7436 	 Train RMAE: 0.8623
# [Epoch: 183 	 Valid MAE: 1.1860
# [Epoch: 183 	 Train MAE: 0.9047
# EarlyStopping counter: 9 out of 30
# Train Epoch: 184 [24/21624] 	 Train Loss(MAE): 0.6040 	 Train RMAE: 0.7772
# Train Epoch: 184 [4824/21624] 	 Train Loss(MAE): 0.6084 	 Train RMAE: 0.7800
# Train Epoch: 184 [9624/21624] 	 Train Loss(MAE): 0.8774 	 Train RMAE: 0.9367
# Train Epoch: 184 [14424/21624] 	 Train Loss(MAE): 0.4168 	 Train RMAE: 0.6456
# Train Epoch: 184 [19224/21624] 	 Train Loss(MAE): 0.4014 	 Train RMAE: 0.6335
# [Epoch: 184 	 Valid MAE: 1.1953
# [Epoch: 184 	 Train MAE: 0.9068
# EarlyStopping counter: 10 out of 30
# Train Epoch: 185 [24/21624] 	 Train Loss(MAE): 0.9988 	 Train RMAE: 0.9994
# Train Epoch: 185 [4824/21624] 	 Train Loss(MAE): 0.7403 	 Train RMAE: 0.8604
# Train Epoch: 185 [9624/21624] 	 Train Loss(MAE): 0.7073 	 Train RMAE: 0.8410
# Train Epoch: 185 [14424/21624] 	 Train Loss(MAE): 0.4227 	 Train RMAE: 0.6502
# Train Epoch: 185 [19224/21624] 	 Train Loss(MAE): 1.0086 	 Train RMAE: 1.0043
# [Epoch: 185 	 Valid MAE: 1.1902
# [Epoch: 185 	 Train MAE: 0.9055
# Epoch   185: reducing learning rate of group 0 to 7.8125e-05.
# EarlyStopping counter: 11 out of 30
# Train Epoch: 186 [24/21624] 	 Train Loss(MAE): 1.1079 	 Train RMAE: 1.0526
# Train Epoch: 186 [4824/21624] 	 Train Loss(MAE): 0.7541 	 Train RMAE: 0.8684
# Train Epoch: 186 [9624/21624] 	 Train Loss(MAE): 0.9297 	 Train RMAE: 0.9642
# Train Epoch: 186 [14424/21624] 	 Train Loss(MAE): 1.4799 	 Train RMAE: 1.2165
# Train Epoch: 186 [19224/21624] 	 Train Loss(MAE): 1.2678 	 Train RMAE: 1.1260
# [Epoch: 186 	 Valid MAE: 1.1905
# [Epoch: 186 	 Train MAE: 0.8984
# EarlyStopping counter: 12 out of 30
# Train Epoch: 187 [24/21624] 	 Train Loss(MAE): 0.4765 	 Train RMAE: 0.6903
# Train Epoch: 187 [4824/21624] 	 Train Loss(MAE): 0.7326 	 Train RMAE: 0.8559
# Train Epoch: 187 [9624/21624] 	 Train Loss(MAE): 1.4373 	 Train RMAE: 1.1989
# Train Epoch: 187 [14424/21624] 	 Train Loss(MAE): 0.6852 	 Train RMAE: 0.8278
# Train Epoch: 187 [19224/21624] 	 Train Loss(MAE): 0.8785 	 Train RMAE: 0.9373
# [Epoch: 187 	 Valid MAE: 1.1836
# [Epoch: 187 	 Train MAE: 0.8977
# EarlyStopping counter: 13 out of 30
# Train Epoch: 188 [24/21624] 	 Train Loss(MAE): 1.0819 	 Train RMAE: 1.0402
# Train Epoch: 188 [4824/21624] 	 Train Loss(MAE): 0.6718 	 Train RMAE: 0.8196
# Train Epoch: 188 [9624/21624] 	 Train Loss(MAE): 1.9680 	 Train RMAE: 1.4029
# Train Epoch: 188 [14424/21624] 	 Train Loss(MAE): 0.6364 	 Train RMAE: 0.7978
# Train Epoch: 188 [19224/21624] 	 Train Loss(MAE): 0.6420 	 Train RMAE: 0.8012
# [Epoch: 188 	 Valid MAE: 1.1885
# [Epoch: 188 	 Train MAE: 0.8973
# EarlyStopping counter: 14 out of 30
# Train Epoch: 189 [24/21624] 	 Train Loss(MAE): 1.4606 	 Train RMAE: 1.2086
# Train Epoch: 189 [4824/21624] 	 Train Loss(MAE): 0.8993 	 Train RMAE: 0.9483
# Train Epoch: 189 [9624/21624] 	 Train Loss(MAE): 0.8027 	 Train RMAE: 0.8960
# Train Epoch: 189 [14424/21624] 	 Train Loss(MAE): 0.8639 	 Train RMAE: 0.9294
# Train Epoch: 189 [19224/21624] 	 Train Loss(MAE): 0.7129 	 Train RMAE: 0.8443
# [Epoch: 189 	 Valid MAE: 1.1898
# [Epoch: 189 	 Train MAE: 0.8965
# EarlyStopping counter: 15 out of 30
# Train Epoch: 190 [24/21624] 	 Train Loss(MAE): 0.8735 	 Train RMAE: 0.9346
# Train Epoch: 190 [4824/21624] 	 Train Loss(MAE): 1.0342 	 Train RMAE: 1.0170
# Train Epoch: 190 [9624/21624] 	 Train Loss(MAE): 0.9164 	 Train RMAE: 0.9573
# Train Epoch: 190 [14424/21624] 	 Train Loss(MAE): 0.9083 	 Train RMAE: 0.9530
# Train Epoch: 190 [19224/21624] 	 Train Loss(MAE): 1.2099 	 Train RMAE: 1.0999
# [Epoch: 190 	 Valid MAE: 1.1862
# [Epoch: 190 	 Train MAE: 0.8964
# EarlyStopping counter: 16 out of 30
# Train Epoch: 191 [24/21624] 	 Train Loss(MAE): 0.7769 	 Train RMAE: 0.8814
# Train Epoch: 191 [4824/21624] 	 Train Loss(MAE): 0.8403 	 Train RMAE: 0.9167
# Train Epoch: 191 [9624/21624] 	 Train Loss(MAE): 1.1275 	 Train RMAE: 1.0618
# Train Epoch: 191 [14424/21624] 	 Train Loss(MAE): 0.7695 	 Train RMAE: 0.8772
# Train Epoch: 191 [19224/21624] 	 Train Loss(MAE): 0.8777 	 Train RMAE: 0.9369
# [Epoch: 191 	 Valid MAE: 1.1849
# [Epoch: 191 	 Train MAE: 0.8966
# EarlyStopping counter: 17 out of 30
# Train Epoch: 192 [24/21624] 	 Train Loss(MAE): 0.8792 	 Train RMAE: 0.9377
# Train Epoch: 192 [4824/21624] 	 Train Loss(MAE): 1.3338 	 Train RMAE: 1.1549
# Train Epoch: 192 [9624/21624] 	 Train Loss(MAE): 0.8850 	 Train RMAE: 0.9407
# Train Epoch: 192 [14424/21624] 	 Train Loss(MAE): 0.5993 	 Train RMAE: 0.7742
# Train Epoch: 192 [19224/21624] 	 Train Loss(MAE): 0.6358 	 Train RMAE: 0.7974
# [Epoch: 192 	 Valid MAE: 1.1859
# [Epoch: 192 	 Train MAE: 0.8958
# EarlyStopping counter: 18 out of 30
# Train Epoch: 193 [24/21624] 	 Train Loss(MAE): 0.7741 	 Train RMAE: 0.8799
# Train Epoch: 193 [4824/21624] 	 Train Loss(MAE): 1.0496 	 Train RMAE: 1.0245
# Train Epoch: 193 [9624/21624] 	 Train Loss(MAE): 1.2296 	 Train RMAE: 1.1089
# Train Epoch: 193 [14424/21624] 	 Train Loss(MAE): 0.7192 	 Train RMAE: 0.8481
# Train Epoch: 193 [19224/21624] 	 Train Loss(MAE): 0.9576 	 Train RMAE: 0.9786
# [Epoch: 193 	 Valid MAE: 1.1857
# [Epoch: 193 	 Train MAE: 0.8965
# EarlyStopping counter: 19 out of 30
# Train Epoch: 194 [24/21624] 	 Train Loss(MAE): 0.6949 	 Train RMAE: 0.8336
# Train Epoch: 194 [4824/21624] 	 Train Loss(MAE): 0.8475 	 Train RMAE: 0.9206
# Train Epoch: 194 [9624/21624] 	 Train Loss(MAE): 1.4490 	 Train RMAE: 1.2037
# Train Epoch: 194 [14424/21624] 	 Train Loss(MAE): 0.6368 	 Train RMAE: 0.7980
# Train Epoch: 194 [19224/21624] 	 Train Loss(MAE): 0.9742 	 Train RMAE: 0.9870
# [Epoch: 194 	 Valid MAE: 1.1883
# [Epoch: 194 	 Train MAE: 0.8957
# EarlyStopping counter: 20 out of 30
# Train Epoch: 195 [24/21624] 	 Train Loss(MAE): 0.4835 	 Train RMAE: 0.6953
# Train Epoch: 195 [4824/21624] 	 Train Loss(MAE): 1.6257 	 Train RMAE: 1.2750
# Train Epoch: 195 [9624/21624] 	 Train Loss(MAE): 0.5838 	 Train RMAE: 0.7641
# Train Epoch: 195 [14424/21624] 	 Train Loss(MAE): 0.9006 	 Train RMAE: 0.9490
# Train Epoch: 195 [19224/21624] 	 Train Loss(MAE): 1.0461 	 Train RMAE: 1.0228
# [Epoch: 195 	 Valid MAE: 1.1907
# [Epoch: 195 	 Train MAE: 0.8952
# EarlyStopping counter: 21 out of 30
# Train Epoch: 196 [24/21624] 	 Train Loss(MAE): 0.5797 	 Train RMAE: 0.7614
# Train Epoch: 196 [4824/21624] 	 Train Loss(MAE): 0.9907 	 Train RMAE: 0.9953
# Train Epoch: 196 [9624/21624] 	 Train Loss(MAE): 0.9070 	 Train RMAE: 0.9523
# Train Epoch: 196 [14424/21624] 	 Train Loss(MAE): 0.8867 	 Train RMAE: 0.9417
# Train Epoch: 196 [19224/21624] 	 Train Loss(MAE): 0.7945 	 Train RMAE: 0.8914
# [Epoch: 196 	 Valid MAE: 1.1865
# [Epoch: 196 	 Train MAE: 0.8953
# Epoch   196: reducing learning rate of group 0 to 3.9063e-05.
# EarlyStopping counter: 22 out of 30
# Train Epoch: 197 [24/21624] 	 Train Loss(MAE): 0.7028 	 Train RMAE: 0.8384
# Train Epoch: 197 [4824/21624] 	 Train Loss(MAE): 0.6078 	 Train RMAE: 0.7796
# Train Epoch: 197 [9624/21624] 	 Train Loss(MAE): 0.7974 	 Train RMAE: 0.8930
# Train Epoch: 197 [14424/21624] 	 Train Loss(MAE): 0.7698 	 Train RMAE: 0.8774
# Train Epoch: 197 [19224/21624] 	 Train Loss(MAE): 1.0681 	 Train RMAE: 1.0335
# [Epoch: 197 	 Valid MAE: 1.1867
# [Epoch: 197 	 Train MAE: 0.8918
# EarlyStopping counter: 23 out of 30
# Train Epoch: 198 [24/21624] 	 Train Loss(MAE): 0.3196 	 Train RMAE: 0.5653
# Train Epoch: 198 [4824/21624] 	 Train Loss(MAE): 0.8380 	 Train RMAE: 0.9154
# Train Epoch: 198 [9624/21624] 	 Train Loss(MAE): 0.8290 	 Train RMAE: 0.9105
# Train Epoch: 198 [14424/21624] 	 Train Loss(MAE): 0.8566 	 Train RMAE: 0.9255
# Train Epoch: 198 [19224/21624] 	 Train Loss(MAE): 1.1592 	 Train RMAE: 1.0767
# [Epoch: 198 	 Valid MAE: 1.1879
# [Epoch: 198 	 Train MAE: 0.8912
# EarlyStopping counter: 24 out of 30
# Train Epoch: 199 [24/21624] 	 Train Loss(MAE): 0.8140 	 Train RMAE: 0.9022
# Train Epoch: 199 [4824/21624] 	 Train Loss(MAE): 0.5801 	 Train RMAE: 0.7617
# Train Epoch: 199 [9624/21624] 	 Train Loss(MAE): 0.6963 	 Train RMAE: 0.8345
# Train Epoch: 199 [14424/21624] 	 Train Loss(MAE): 0.7071 	 Train RMAE: 0.8409
# Train Epoch: 199 [19224/21624] 	 Train Loss(MAE): 0.5281 	 Train RMAE: 0.7267
# [Epoch: 199 	 Valid MAE: 1.1881
# [Epoch: 199 	 Train MAE: 0.8912
# EarlyStopping counter: 25 out of 30
# Train Epoch: 200 [24/21624] 	 Train Loss(MAE): 0.8432 	 Train RMAE: 0.9182
# Train Epoch: 200 [4824/21624] 	 Train Loss(MAE): 1.1359 	 Train RMAE: 1.0658
# Train Epoch: 200 [9624/21624] 	 Train Loss(MAE): 1.0328 	 Train RMAE: 1.0162
# Train Epoch: 200 [14424/21624] 	 Train Loss(MAE): 0.3000 	 Train RMAE: 0.5478
# Train Epoch: 200 [19224/21624] 	 Train Loss(MAE): 0.9174 	 Train RMAE: 0.9578
# [Epoch: 200 	 Valid MAE: 1.1931
# [Epoch: 200 	 Train MAE: 0.8913
# EarlyStopping counter: 26 out of 30
# Train Epoch: 201 [24/21624] 	 Train Loss(MAE): 1.2890 	 Train RMAE: 1.1354
# Train Epoch: 201 [4824/21624] 	 Train Loss(MAE): 0.4560 	 Train RMAE: 0.6752
# Train Epoch: 201 [9624/21624] 	 Train Loss(MAE): 1.6683 	 Train RMAE: 1.2916
# Train Epoch: 201 [14424/21624] 	 Train Loss(MAE): 0.8259 	 Train RMAE: 0.9088
# Train Epoch: 201 [19224/21624] 	 Train Loss(MAE): 0.9550 	 Train RMAE: 0.9773
# [Epoch: 201 	 Valid MAE: 1.1852
# [Epoch: 201 	 Train MAE: 0.8910
# EarlyStopping counter: 27 out of 30
# Train Epoch: 202 [24/21624] 	 Train Loss(MAE): 0.8620 	 Train RMAE: 0.9285
# Train Epoch: 202 [4824/21624] 	 Train Loss(MAE): 1.5772 	 Train RMAE: 1.2559
# Train Epoch: 202 [9624/21624] 	 Train Loss(MAE): 0.8091 	 Train RMAE: 0.8995
# Train Epoch: 202 [14424/21624] 	 Train Loss(MAE): 0.5287 	 Train RMAE: 0.7271
# Train Epoch: 202 [19224/21624] 	 Train Loss(MAE): 0.6272 	 Train RMAE: 0.7919
# [Epoch: 202 	 Valid MAE: 1.1904
# [Epoch: 202 	 Train MAE: 0.8902
# EarlyStopping counter: 28 out of 30
# Train Epoch: 203 [24/21624] 	 Train Loss(MAE): 0.7967 	 Train RMAE: 0.8926
# Train Epoch: 203 [4824/21624] 	 Train Loss(MAE): 0.8854 	 Train RMAE: 0.9410
# Train Epoch: 203 [9624/21624] 	 Train Loss(MAE): 0.9295 	 Train RMAE: 0.9641
# Train Epoch: 203 [14424/21624] 	 Train Loss(MAE): 1.4878 	 Train RMAE: 1.2198
# Train Epoch: 203 [19224/21624] 	 Train Loss(MAE): 0.6426 	 Train RMAE: 0.8016
# [Epoch: 203 	 Valid MAE: 1.1874
# [Epoch: 203 	 Train MAE: 0.8903
# EarlyStopping counter: 29 out of 30
# Train Epoch: 204 [24/21624] 	 Train Loss(MAE): 0.7585 	 Train RMAE: 0.8709
# Train Epoch: 204 [4824/21624] 	 Train Loss(MAE): 0.4512 	 Train RMAE: 0.6717
# Train Epoch: 204 [9624/21624] 	 Train Loss(MAE): 0.8055 	 Train RMAE: 0.8975
# Train Epoch: 204 [14424/21624] 	 Train Loss(MAE): 1.2193 	 Train RMAE: 1.1042
# Train Epoch: 204 [19224/21624] 	 Train Loss(MAE): 0.7962 	 Train RMAE: 0.8923
# [Epoch: 204 	 Valid MAE: 1.1858
# [Epoch: 204 	 Train MAE: 0.8905
# EarlyStopping counter: 30 out of 30
# Early stopping

# %%
print('Valid best:',best_mae)
print('Train best:',best_train_mae)
# Out:
# Valid best: 1.181448501295748
# Train best: 0.90912150255054

# %% [markdown]
# # Epoch visualization

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(train_mae_list, ls='-', color='blue', label='train')
ax1.set_ylim(0,5)

ax2 = ax1.twinx()
ax2.plot(valid_mae_list, ls='--', color='red', label='valid')
ax2.set_ylim(0,5)

ax1.set_title('MAE error')
ax1.legend(loc='upper right')
ax2.legend(loc='upper left')
plt.show()

# %%
# 가중치 가져오기
model = Zloc_Estimaotor(input_dim, hidden_dim,layer_dim)
model.load_state_dict(torch.load('./weights/ODD_LSTM_612_iou4.pth'))
model.eval()
model.to(device)
# Out:
# Zloc_Estimaotor(
#   (rnn): LSTM(15, 612, num_layers=3, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=612, out_features=294, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=294, out_features=146, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=146, out_features=72, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=72, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # Predict Train

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=len(df_train), shuffle=False)
for idx, batch in enumerate(train_dataloader):
    if idx == 1:
        break
    train_pred = batch[0]
predict_zloc = model(train_pred.reshape(-1,1,input_dim).to(device))

# %%
df_train['predict'] = predict_zloc.cpu().detach().numpy()
df_train[['zloc','predict']].head(10)
# Out:
#     zloc    predict
# 0  33.26  33.377369
# 1  44.06  44.166389
# 2  48.93  48.892540
# 3  53.00  49.797523
# 4  15.60  15.960265
# 5  35.56  35.082996
# 6  17.76  18.502769
# 7   6.08   6.290573
# 8  33.44  33.400146
# 9  20.77  20.068243

# %%
import numpy as np
abs0 = np.abs(df_train.zloc-df_train.predict)
abs0
# Out:
# 0        0.117369
# 1        0.106389
# 2        0.037460
# 3        3.202477
# 4        0.360265
#            ...
# 21611    0.085173
# 21612    0.640209
# 21613    0.360530
# 21614    1.404688
# 21615    2.020979
# Length: 21616, dtype: float64

# %%
sum(abs0/len(df_train))
# Out:
# 0.9026711600485083

# %%
np.mean(np.square(df_train['zloc']-df_train['predict']))**(1/2)
# Out:
# 1.7234558804978621

# %%
func = np.sum(np.abs((df_train.predict - df_train.zloc))/(df_train.predict))
men = func/len(df_train)
1-men
# Out:
# 0.9656529279959514

# %% [markdown]
# # Predict Valid

# %%
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=len(df_train), shuffle=False)
for idx, batch in enumerate(valid_dataloader):
    if idx == 1:
        break
    valid_pred = batch[0]
predict_zloc = model(valid_pred.reshape(-1,1,input_dim).to(device))

# %%
df_valid['predict'] = predict_zloc.cpu().detach().numpy()
df_valid[['zloc','predict']].head(10)
# Out:
#     zloc    predict
# 0  36.41  35.257492
# 1  37.96  36.484116
# 2  11.97  11.469759
# 3  41.95  47.231674
# 4  16.34  16.368952
# 5   4.65   4.988996
# 6  32.70  32.263947
# 7  42.93  43.405777
# 8  57.66  59.439499
# 9   9.71   8.764616

# %%
abs0 = np.abs(df_valid.zloc-df_valid.predict)
abs0
# Out:
# 0       1.152508
# 1       1.475884
# 2       0.500241
# 3       5.281674
# 4       0.028952
#           ...
# 2697    3.961287
# 2698    0.042835
# 2699    0.272183
# 2700    0.773530
# 2701    0.349957
# Length: 2702, dtype: float64

# %%
sum(abs0/len(df_valid))
# Out:
# 1.1824791377107775

# %%
np.mean(np.square(df_valid['zloc']-df_valid['predict']))**(1/2)
# Out:
# 2.0910257118818976

# %%
func = np.sum(np.abs((df_valid.predict - df_valid.zloc))/(df_valid.predict))
men = func/len(df_valid)
1-men
# Out:
# 0.9541682118413244

# %% [markdown]
# # Predict Test

# %%
test_mse, test_rmse = evaluate(model, test_dataloader)
print('Test MAE: {:4f} \t Test RMAE: {:4f}'.format(test_mse, test_rmse))
# Out:
# Test MAE: 1.219974 	 Test RMAE: 1.104524

# %%
# look dataset
for idx, batch in enumerate(test_dataloader):
    if idx == 1:
        break
    test_pred = batch[0]
predict_zloc = model(test_pred.reshape(-1,1,input_dim).to(device))

# %%
df_test['predict'] = predict_zloc.cpu().detach().numpy()
df_test[['zloc','predict']].head(10)
# Out:
#     zloc    predict
# 0  23.91  23.779802
# 1  22.08  22.115099
# 2  17.59  17.544466
# 3  15.68  15.697229
# 4  53.67  53.481613
# 5  14.61  14.675043
# 6   7.93   7.724176
# 7  26.44  27.459673
# 8  50.67  49.509689
# 9  56.22  58.008438

# %%
import numpy as np
abs0 = np.abs(df_test.zloc-df_test.predict)
abs0
# Out:
# 0       0.130198
# 1       0.035099
# 2       0.045534
# 3       0.017229
# 4       0.188387
#           ...
# 2698    1.441285
# 2699    0.259637
# 2700    0.233844
# 2701    0.611654
# 2702    0.183987
# Length: 2703, dtype: float64

# %%
sum(abs0/len(df_test))
# Out:
# 1.2199737735717264

# %%
np.mean(np.square(df_test['zloc']-df_test['predict']))**(1/2)
# Out:
# 2.2415832764287247

# %%
func = np.sum(np.abs((df_test.predict - df_test.zloc))/(df_test.predict))
men = func/len(df_test)
1-men
# Out:
# 0.9521917958082725

# %% [markdown]
# ### 구간 나눠서 정확도 계산해보기

# %%
first = df_test[df_test['zloc']<=10]
func1 = np.sum(np.abs((first.predict - first.zloc))/(first.predict))
men1 = func1/len(first)
1-men1
# Out:
# 0.9292780413215092

# %%
mask = (df_test['zloc']>=10) & (df_test['zloc']<20)
second = df_test[mask]
func2 = np.sum(np.abs((second.predict - second.zloc))/(second.predict))
men2 = func2/len(second)
1-men2
# Out:
# 0.9641430964021086

# %%
mask = (df_test['zloc']>=20) & (df_test['zloc']<30)
third = df_test[mask]
func3 = np.sum(np.abs((third.predict - third.zloc))/(third.predict))
men3 = func3/len(third)
1-men3
# Out:
# 0.9617308826919295

# %%
mask = (df_test['zloc']>=30) & (df_test['zloc']<40)
fourth = df_test[mask]
func4 = np.sum(np.abs((fourth.predict - fourth.zloc))/(fourth.predict))
men4 = func4/len(fourth)
1-men4
# Out:
# 0.9536270769034572

# %%
mask = (df_test['zloc']>=40) & (df_test['zloc']<50)
fifth = df_test[mask]
func5 = np.sum(np.abs((fifth.predict - fifth.zloc))/(fifth.predict))
men5 = func5/len(fifth)
1-men5
# Out:
# 0.9511991349365575

# %%
mask = (df_test['zloc']>=50) & (df_test['zloc']<60)
sixth = df_test[mask]
func6 = np.sum(np.abs((sixth.predict - sixth.zloc))/(sixth.predict))
men6 = func6/len(sixth)
1-men6
# Out:
# 0.9451811834911445

# %%
mask = (df_test['zloc']>=60) & (df_test['zloc']<70)
seventh = df_test[mask]
func7 = np.sum(np.abs((seventh.predict - seventh.zloc))/(seventh.predict))
men7 = func7/len(seventh)
1-men7
# Out:
# 0.9375939088662171

# %%
acc_list = []
for i in range(1,12):
    mask = (df_test['zloc']<i*10) & (df_test['zloc'] >= i)
    data = df_test[mask]
    value = np.sum(np.abs((data.predict - data.zloc))/(data.predict))
    output = value/len(data)
    acc_list.append(1-output)

# %%
acc_list
# Out:
# [0.9292222695942318,
#  0.9508433121692339,
#  0.9557812313803546,
#  0.9581238858258856,
#  0.9586695839802325,
#  0.9581438641884256,
#  0.9578240488203149,
#  0.9574140710112151,
#  0.9571890215935799,
#  0.957026402758832,
#  0.9569121436323509]

# %% [markdown]
# # Visualization

# %%
df_train.plot(kind='scatter', x='zloc', y='depth_mean', marker='o', alpha=0.3, s=50, figsize=(20,10), color='blue')
plt.show()

# %%
df_train.plot(kind='scatter', x='predict', y='zloc', marker='o', alpha=0.3, s=50, figsize=(10,10), color='blue')
plt.show()

# %%
df_valid.plot(kind='scatter', x='predict', y='zloc', marker='o', alpha=0.3, s=50, figsize=(10,10), color='blue')
plt.show()

# %%
df_test.plot(kind='scatter', x='predict', y='zloc', marker='o', alpha=0.3, s=50, figsize=(10,10), color='blue')
# Out:
# <AxesSubplot:xlabel='predict', ylabel='zloc'>

# %%
z = df_train['zloc']
#print(z)

plt.style.use('ggplot')
df_train.plot(kind='scatter', x='predict', y='depth_mean', marker='o', cmap='viridis', c=z, alpha=0.5, s=50, 
              figsize=(30,10))
plt.xlabel('predict')
plt.title('predict-depth_mean')
plt.show()
